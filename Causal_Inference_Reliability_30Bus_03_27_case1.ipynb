# %% [markdown]
# ### Statistical and Grid network package

# %%
import os
import numpy as np
from tqdm import tqdm
import pandas as pd
import pandapower as pp
import networkx as nx
import pandapower.networks as pn
import pandapower.plotting as plot
from pandapower.control import ConstControl
from pandapower.timeseries import DFData, OutputWriter, run_timeseries
import matplotlib.pyplot as plt
from scipy.stats import norm
from dowhy import CausalModel
from pandapower.pypower.makeYbus import makeYbus
import scipy.linalg
import scipy.sparse as sp

# %% [markdown]
# ### Causal Inference Package

# %%
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils
from causallearn.utils.cit import fisherz
from sklearn.preprocessing import StandardScaler
from scipy.special import psi
import matplotlib.pyplot as plt
from dowhy import gcm # Graphical Causal Models

# %%
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### Define the Function to check N-1 contingency criterion

# %%
# Define function to check whether the network meet the N-1 contingency criterion
def check_n_1_contingency(net):
    critical_elements = []
    
    # Backup original network
    original_net = net.deepcopy()
    
    # Test line outages
    for line in net.line.index:
        net_copy = original_net.deepcopy()
        net_copy.line.at[line, "in_service"] = False  # Remove one line
        try:
            pp.runpp(net_copy, algorithm="nr")
        except pp.powerflow.LoadflowNotConverged:
            critical_elements.append(f"Line {line} outage causes failure.")
            continue
        
        # Check for overloads
        if any(net_copy.res_line.loading_percent > 100):
            critical_elements.append(f"Line {line} outage causes overloads.")

    # Test generator outages
    for gen in net.gen.index:
        net_copy = original_net.deepcopy()
        net_copy.gen.at[gen, "in_service"] = False  # Remove one generator
        try:
            pp.runpp(net_copy, algorithm="nr")
        except pp.powerflow.LoadflowNotConverged:
            critical_elements.append(f"Generator {gen} outage causes failure.")
            continue

        # Check for voltage violations
        if any((net_copy.res_bus.vm_pu < 0.95) | (net_copy.res_bus.vm_pu > 1.05)):
            critical_elements.append(f"Generator {gen} outage causes voltage issues.")

    return critical_elements

# %% [markdown]
# ### Load the Network Testcase

# %%
# Load the 30-bus system
net = pn.case30()

# %% [markdown]
# ### The function reinforce the network to meet the criterion

# %%
# Function to Reinforce the network based on contingency violations
def reinforce_network(net):
    original_net = net.deepcopy()
    
    # Identify problematic lines
    overloaded_lines = []
    for line in net.line.index:
        net_copy = original_net.deepcopy()
        net_copy.line.at[line, "in_service"] = False  # Simulate line outage
        try:
            pp.runpp(net_copy)
        except pp.powerflow.LoadflowNotConverged:
            overloaded_lines.append(line)
            continue
        if any(net_copy.res_line.loading_percent > 100):
            overloaded_lines.append(line)
    
    # Add parallel lines to overloaded lines
    for line in overloaded_lines:
        from_bus = net.line.loc[line, "from_bus"]
        to_bus = net.line.loc[line, "to_bus"]
        print(f"Adding parallel line between Bus {from_bus} and Bus {to_bus} to mitigate overload.")
        pp.create_line_from_parameters(net, from_bus=from_bus, to_bus=to_bus, 
                                       length_km=1.0, r_ohm_per_km=0.05, 
                                       x_ohm_per_km=0.1, c_nf_per_km=0, 
                                       max_i_ka=1.5)  # Higher capacity
    
    # Identify problematic generators
    problematic_gens = []
    for gen in net.gen.index:
        net_copy = original_net.deepcopy()
        net_copy.gen.at[gen, "in_service"] = False  # Simulate generator outage
        try:
            pp.runpp(net_copy)
        except pp.powerflow.LoadflowNotConverged:
            problematic_gens.append(gen)
            continue
        if any((net_copy.res_bus.vm_pu < 0.95) | (net_copy.res_bus.vm_pu > 1.05)):
            problematic_gens.append(gen)

    # Increase generator capacities to provide redundancy
    for gen in problematic_gens:
        net.gen.at[gen, "p_mw"] *= 1.2  # Increase power generation by 20%
        print(f"Increasing capacity of Generator {gen} to improve voltage stability.")

    return net

# Reinforce the network
net = reinforce_network(net)

# Run contingency check again
pp.runpp(net)
print("Reinforced system power flow successful.")

# Check if violations still exist
violations = check_n_1_contingency(net)
if violations:
    print("grid netwrok still has issues under N-1 contingency.")
    for v in violations:
        print(v)
else:
    print("The grid netwrok satisfies the N-1 contingency criterion!")
# Out:
# Adding parallel line between Bus 0 and Bus 1 to mitigate overload.
# Adding parallel line between Bus 0 and Bus 2 to mitigate overload.
# Adding parallel line between Bus 1 and Bus 3 to mitigate overload.
# Adding parallel line between Bus 2 and Bus 3 to mitigate overload.
# Adding parallel line between Bus 1 and Bus 4 to mitigate overload.
# Adding parallel line between Bus 1 and Bus 5 to mitigate overload.
# Adding parallel line between Bus 3 and Bus 5 to mitigate overload.
# Adding parallel line between Bus 4 and Bus 6 to mitigate overload.
# Adding parallel line between Bus 5 and Bus 6 to mitigate overload.
# Adding parallel line between Bus 5 and Bus 7 to mitigate overload.
# Adding parallel line between Bus 5 and Bus 8 to mitigate overload.
# Adding parallel line between Bus 5 and Bus 9 to mitigate overload.
# Adding parallel line between Bus 8 and Bus 10 to mitigate overload.
# Adding parallel line between Bus 8 and Bus 9 to mitigate overload.
# Adding parallel line between Bus 3 and Bus 11 to mitigate overload.
# Adding parallel line between Bus 11 and Bus 12 to mitigate overload.
# Adding parallel line between Bus 11 and Bus 13 to mitigate overload.
# Adding parallel line between Bus 11 and Bus 14 to mitigate overload.
# Adding parallel line between Bus 11 and Bus 15 to mitigate overload.
# Adding parallel line between Bus 13 and Bus 14 to mitigate overload.
# Adding parallel line between Bus 15 and Bus 16 to mitigate overload.
# Adding parallel line between Bus 14 and Bus 17 to mitigate overload.
# Adding parallel line between Bus 17 and Bus 18 to mitigate overload.
# Adding parallel line between Bus 18 and Bus 19 to mitigate overload.
# Adding parallel line between Bus 9 and Bus 19 to mitigate overload.
# Adding parallel line between Bus 9 and Bus 16 to mitigate overload.
# Adding parallel line between Bus 9 and Bus 20 to mitigate overload.
# Adding parallel line between Bus 9 and Bus 21 to mitigate overload.
# Adding parallel line between Bus 20 and Bus 21 to mitigate overload.
# Adding parallel line between Bus 14 and Bus 22 to mitigate overload.
# Adding parallel line between Bus 21 and Bus 23 to mitigate overload.
# Adding parallel line between Bus 22 and Bus 23 to mitigate overload.
# Adding parallel line between Bus 23 and Bus 24 to mitigate overload.
# Adding parallel line between Bus 24 and Bus 25 to mitigate overload.
# Adding parallel line between Bus 24 and Bus 26 to mitigate overload.
# Adding parallel line between Bus 27 and Bus 26 to mitigate overload.
# Adding parallel line between Bus 26 and Bus 28 to mitigate overload.
# Adding parallel line between Bus 26 and Bus 29 to mitigate overload.
# Adding parallel line between Bus 28 and Bus 29 to mitigate overload.
# Adding parallel line between Bus 7 and Bus 27 to mitigate overload.
# Adding parallel line between Bus 5 and Bus 27 to mitigate overload.
# Increasing capacity of Generator 0 to improve voltage stability.
# Increasing capacity of Generator 1 to improve voltage stability.
# Increasing capacity of Generator 2 to improve voltage stability.
# Reinforced system power flow successful.
# The grid netwrok satisfies the N-1 contingency criterion!

# %% [markdown]
# ##  Show Network Basic Information

# %% [markdown]
# ### The PV bus (generators) information

# %%
# View all generator (gen) information and Slack bus
gen_info = net.gen
print(gen_info)
print(net.ext_grid)

# Print the bus number where the generator is located
pv_bus_numbers = net.gen['bus'].values
print("Generator (PV) bus numbers:", pv_bus_numbers)

# Identify the 5 PV buses in the 30-bus system
pv_buses = [1, 21, 26, 22, 12]
# Out:
#    name  bus    p_mw  vm_pu  sn_mva  min_q_mvar  max_q_mvar  scaling  slack  \
# 0  None    1  73.164    1.0     NaN       -20.0        60.0      1.0  False
# 1  None   21  25.908    1.0     NaN       -15.0        62.5      1.0  False
# 2  None   26  32.292    1.0     NaN       -15.0        48.7      1.0  False
# 3  None   22  19.200    1.0     NaN       -10.0        40.0      1.0  False
# 4  None   12  37.000    1.0     NaN       -15.0        44.7      1.0  False
#
#    in_service  slack_weight  type  controllable  max_p_mw  min_p_mw
# 0        True           0.0  None          True      80.0       0.0
# 1        True           0.0  None          True      50.0       0.0
# 2        True           0.0  None          True      55.0       0.0
# 3        True           0.0  None          True      30.0       0.0
# 4        True           0.0  None          True      40.0       0.0
#    name  bus  vm_pu  va_degree  slack_weight  in_service  max_p_mw  min_p_mw  \
# 0  None    0    1.0        0.0           1.0        True      80.0       0.0
#
#    max_q_mvar  min_q_mvar
# 0       150.0       -20.0
# Generator (PV) bus numbers: [ 1 21 26 22 12]

# %% [markdown]
# ### The load bus information

# %%
# View the bus information of the external power grid (Slack bus)
slack_bus_numbers = net.ext_grid['bus'].values
print("Slack bus numbers:", slack_bus_numbers)

# View load information
print(net.load)

# Calculate total active power and reactive power
total_p = net.load['p_mw'].sum()  # Total active power
total_q = net.load['q_mvar'].sum()  # Total reactive power

print(f"Total active power load of 30-bus system: {total_p} MW")
print(f"Total reactive power load of 30-bus system: {total_q} MVar")
# Out:
# Slack bus numbers: [0]
#     name  bus  p_mw  q_mvar  const_z_percent  const_i_percent  sn_mva  \
# 0   None    1  21.7    12.7              0.0              0.0     NaN
# 1   None    2   2.4     1.2              0.0              0.0     NaN
# 2   None    3   7.6     1.6              0.0              0.0     NaN
# 3   None    6  22.8    10.9              0.0              0.0     NaN
# 4   None    7  30.0    30.0              0.0              0.0     NaN
# 5   None    9   5.8     2.0              0.0              0.0     NaN
# 6   None   11  11.2     7.5              0.0              0.0     NaN
# 7   None   13   6.2     1.6              0.0              0.0     NaN
# 8   None   14   8.2     2.5              0.0              0.0     NaN
# 9   None   15   3.5     1.8              0.0              0.0     NaN
# 10  None   16   9.0     5.8              0.0              0.0     NaN
# 11  None   17   3.2     0.9              0.0              0.0     NaN
# 12  None   18   9.5     3.4              0.0              0.0     NaN
# 13  None   19   2.2     0.7              0.0              0.0     NaN
# 14  None   20  17.5    11.2              0.0              0.0     NaN
# 15  None   22   3.2     1.6              0.0              0.0     NaN
# 16  None   23   8.7     6.7              0.0              0.0     NaN
# 17  None   25   3.5     2.3              0.0              0.0     NaN
# 18  None   28   2.4     0.9              0.0              0.0     NaN
# 19  None   29  10.6     1.9              0.0              0.0     NaN
#
#     scaling  in_service  type  controllable
# 0       1.0        True  None         False
# 1       1.0        True  None         False
# 2       1.0        True  None         False
# 3       1.0        True  None         False
# 4       1.0        True  None         False
# 5       1.0        True  None         False
# 6       1.0        True  None         False
# 7       1.0        True  None         False
# 8       1.0        True  None         False
# 9       1.0        True  None         False
# 10      1.0        True  None         False
# 11      1.0        True  None         False
# 12      1.0        True  None         False
# 13      1.0        True  None         False
# 14      1.0        True  None         False
# 15      1.0        True  None         False
# 16      1.0        True  None         False
# 17      1.0        True  None         False
# 18      1.0        True  None         False
# 19      1.0        True  None         False
# Total active power load of 30-bus system: 189.2 MW
# Total reactive power load of 30-bus system: 107.20000000000002 MVar

# %% [markdown]
# ### The capacity of the conventional generators

# %%
# Initialize an empty list to store installed capacities of each generator
installed_capacities = []

# Loop through each row in the gen_info DataFrame to extract information
for i, row in gen_info.iterrows():
    bus_id = row['bus']  # Get the bus ID for the generator
    installed_capacity = row['max_p_mw']  # Get the installed capacity of the generator in MW
    print(f"Conventional Generator at Bus {bus_id}: Installed Capacity = {installed_capacity} MW")
    installed_capacities.append(installed_capacity)  # Append the capacity to the list

# Calculate the total installed capacity of all generators
total_installed_capacity = sum(installed_capacities)
print(f"Total Installed Capacity = {total_installed_capacity} MW")
# Out:
# Conventional Generator at Bus 1: Installed Capacity = 80.0 MW
# Conventional Generator at Bus 21: Installed Capacity = 50.0 MW
# Conventional Generator at Bus 26: Installed Capacity = 55.0 MW
# Conventional Generator at Bus 22: Installed Capacity = 30.0 MW
# Conventional Generator at Bus 12: Installed Capacity = 40.0 MW
# Total Installed Capacity = 255.0 MW

# %% [markdown]
# ### Deactivate Some Conventional Generators to introduce Solar-Based Energy with static generator (Same Magnitude capacity)
# Replace a deactivated 45 MW conventional generator with a solar-based, variable power source connected to a static generator (sgen) at a bus
# Penetration Level (%)=Installed PV Capacity/Total Installed Generation Capacity×100= 80/255=30.1%
# case2: not drop out the conventional

# %%
# Deactive specific generators(bus 21 22) # Make the solar-based generators more significant
# Drop Around 45 MW Acive Power with the conventional generators / with 80mw capacity
net.gen.drop(net.gen[net.gen['bus'].isin([21,22])].index, inplace=True)

# Verify the remaining generators
print(net.gen)
# Out:
#    name  bus    p_mw  vm_pu  sn_mva  min_q_mvar  max_q_mvar  scaling  slack  \
# 0  None    1  73.164    1.0     NaN       -20.0        60.0      1.0  False
# 2  None   26  32.292    1.0     NaN       -15.0        48.7      1.0  False
# 4  None   12  37.000    1.0     NaN       -15.0        44.7      1.0  False
#
#    in_service  slack_weight  type  controllable  max_p_mw  min_p_mw
# 0        True           0.0  None          True      80.0       0.0
# 2        True           0.0  None          True      55.0       0.0
# 4        True           0.0  None          True      40.0       0.0

# %%
print(net.sgen)
# Out:
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, scaling, in_service, type, current_source]
# Index: []

# %%
# # Inspect generators in the system
# print(net.gen)
# # Define PV buses
# pv_buses = [1, 21, 26, 22, 12]
# installed_capacities =[80, 50, 55, 30, 40]
# # Set a constant power factor value (0.95)
# power_factor = 0.95
# # Create PV static generators with constnt factor mode reactive power
# for bus, installed_capacity in zip(pv_buses, installed_capacities):
#     p_mw = installed_capacity  # Active power
#     q_mvar = p_mw * np.tan(np.arccos(power_factor))  # Calculate Q based on the power factor
#     pp.create_sgen(net, bus, p_mw=0, q_mvar=q_mvar, max_p_mw=installed_capacity, name=f"PV_bus_{bus}")

# # Verify generator table
# print(net.sgen)
# # Fixed means and standard deviations for each PV bus
# pv_bus_means = [20.42496, 12.76560, 14.04216, 7.65936, 10.21248]
# pv_bus_stds = [25.622111, 16.013819, 17.615201, 9.608292, 12.811055]

# %% [markdown]
# ## Load ERCOT Data and Data Processing

# %%
# Load the CSV file with the ERCOT time-series data file
# file_path = 'C:\\Users\\default.DESKTOP-C4C7JDR\\Desktop\\ERCOT SOLAR DATA.xlsx'  # Home PC
file_path = 'C:\\Users\\jliu359\\OneDrive - Syracuse University\\Desktop\\ERCOT SOLAR DATA.xlsx' #Lab PC
ercot_data = pd.read_excel(file_path)
#  Read data
print(ercot_data.head())

# Extract the time and PV generation columns
# Set the time column as the index and ensure it's in datetime format
ercot_data['Time (Hour-Ending)'] = pd.to_datetime(ercot_data['Time (Hour-Ending)'])
ercot_data.set_index('Time (Hour-Ending)', inplace=True)
pv_generation = ercot_data['ERCOT.PVGR.GEN']

#Scale ERCOT solar generation to match the total installed capacity of the added genenator's capacity in the 30-bus system
# 14249 MW is the total solar installed capacity in the ERCOT dataset
# Scaling_factor = total_installed_capacity / 14249 
# Calculate the mean and standard deviation of the PV generation
mean_pv_ercot = pv_generation.mean()
std_pv_ercot= pv_generation.std()

print(f"Mean of PV generation: {mean_pv_ercot:.4f} MW")
print(f"Standard deviation of PV generation: {std_pv_ercot:.4f} MW")

# Prepare a DataFrame to hold profiles for each PV bus with an integer index
profiles_df = pd.DataFrame(index=range(len(ercot_data)))
# Out:
#    Time (Hour-Ending)       Date    ERCOT.LOAD  ERCOT.PVGR.GEN  \
# 0 2023-01-01 01:00:00 2023-01-01  35829.306163        0.449746
# 1 2023-01-01 02:00:00 2023-01-01  35245.390234        0.454733
# 2 2023-01-01 03:00:00 2023-01-01  34599.761810        0.443528
# 3 2023-01-01 04:00:00 2023-01-01  34227.151061        0.458567
# 4 2023-01-01 05:00:00 2023-01-01  34093.414143        0.451126
#
#    Total Solar Installed, MW  Solar Output, % of Load  \
# 0                      14249                 0.001255
# 1                      14249                 0.001290
# 2                      14249                 0.001282
# 3                      14249                 0.001340
# 4                      14249                 0.001323
#
#    Solar Output, % of Installed  Solar 1-hr MW change  Solar 1-hr % change  \
# 0                      0.003156                   NaN                  NaN
# 1                      0.003191                   0.0                  0.0
# 2                      0.003113                   0.0                  0.0
# 3                      0.003218                   0.0                  0.0
# 4                      0.003166                   0.0                  0.0
#
#    Daytime Hour  Ramping Daytime Hour
# 0         False                 False
# 1         False                 False
# 2         False                 False
# 3         False                 False
# 4         False                 False
# Mean of PV generation: 3637.9406 MW
# Standard deviation of PV generation: 4563.6182 MW

# %% [markdown]
# ### Add the Static generators (Solar-Generation) and build the constant power factor control mode with reactive power

# %%
# Define Parameters
total_drop_conventional_capacity= 80  # MW for deactiving the conventional generators
n = 8  # Number of added static（solar) generators (Set this number between 5 and 10)

# Select buses (load buses) to add the solar generation
solar_sgen_buses= [3, 4, 6, 10, 12, 14, 16, 19]  # Buses with the solar-based generator
assert len(solar_sgen_buses) == n, "Number of buses must match number of generators."
# Distribute total PV capacity equally per static generator
solar_installed_capacities_per_sgen = np.full(n, total_drop_conventional_capacity / n)

# Constant power factor 
power_factor = 0.95
q_mvar_per_sgen = solar_installed_capacities_per_sgen * np.tan(np.arccos(power_factor))

# Add static generators
for i, bus in enumerate(solar_sgen_buses):
    pp.create_sgen(net, 
                   bus=bus, 
                   p_mw=0, 
                   q_mvar=q_mvar_per_sgen[i], 
                   max_p_mw=solar_installed_capacities_per_sgen[i], 
                   name=f"Solar_StaticGen_{bus}", 
                   type="solar")

print(f"Added {n} solar-based static generators with {total_drop_conventional_capacity / n:.2f} MW each.")
print(net.sgen)
# Out:
# Added 8 solar-based static generators with 10.00 MW each.
#                  name  bus  p_mw    q_mvar  sn_mva  scaling  in_service  \
# 0   Solar_StaticGen_3    3   0.0  3.286841     NaN      1.0        True
# 1   Solar_StaticGen_4    4   0.0  3.286841     NaN      1.0        True
# 2   Solar_StaticGen_6    6   0.0  3.286841     NaN      1.0        True
# 3  Solar_StaticGen_10   10   0.0  3.286841     NaN      1.0        True
# 4  Solar_StaticGen_12   12   0.0  3.286841     NaN      1.0        True
# 5  Solar_StaticGen_14   14   0.0  3.286841     NaN      1.0        True
# 6  Solar_StaticGen_16   16   0.0  3.286841     NaN      1.0        True
# 7  Solar_StaticGen_19   19   0.0  3.286841     NaN      1.0        True
#
#     type  current_source  max_p_mw
# 0  solar            True      10.0
# 1  solar            True      10.0
# 2  solar            True      10.0
# 3  solar            True      10.0
# 4  solar            True      10.0
# 5  solar            True      10.0
# 6  solar            True      10.0
# 7  solar            True      10.0

# %%
# Calculate base mean and std for each static generator
total_ercot_pv_capacity=14249
scaling_factor = total_drop_conventional_capacity/ (n*total_ercot_pv_capacity)
solar_mean_per_sgen = mean_pv_ercot* scaling_factor
solar_std_per_sgen = mean_pv_ercot * scaling_factor
# Print result
print(f"Scaling factor: {scaling_factor:.6f}")
print(f"Solar mean generation per static generator: {solar_mean_per_sgen:.4f} MW")
print(f"Solar std deviation per static generator: {solar_std_per_sgen:.4f} MW")
# Out:
# Scaling factor: 0.000702
# Solar mean generation per static generator: 2.5531 MW
# Solar std deviation per static generator: 2.5531 MW

# %% [markdown]
# ### The function based on the Z-matrix (Impedance matrix) to Compute the electrical distances (Generators and Loads)
# This function computes the admittance matrix (Ybus) in per unit (p.u.).
# The per-unit admittance is derived from the network base values

# %%
# Function to compute distances from Z-matrix
def compute_distances(bus_indices_1, bus_indices_2, Z_matrix):
    distances = []
    for i in bus_indices_1:
        for j in bus_indices_2:
            if i != j:  # Avoid self-distances
                impedance_distance = abs(Z_matrix[i, j])  # Take absolute impedance value
                distances.append((i, j, impedance_distance))
    return distances

# %% [markdown]
# ### Identify Bus Indices for Conventional and solar Generator and Load Buses

# %%
conventional_gen_buses = net.gen['bus'].tolist()  # Conventional generators
solar_sgen_buses = net.sgen['bus'].tolist()  # Solar PV buses
load_buses = net.load['bus'].tolist()  # Load buses
# Print the lists
print("Conventional Generator Buses:", conventional_gen_buses)
print("Solar Generator Buses:", solar_sgen_buses)
print("Load Buses:", load_buses)
# print("Generator Buses:", gen_buses)
# Out:
# Conventional Generator Buses: [1, 26, 12]
# Solar Generator Buses: [3, 4, 6, 10, 12, 14, 16, 19]
# Load Buses: [1, 2, 3, 6, 7, 9, 11, 13, 14, 15, 16, 17, 18, 19, 20, 22, 23, 25, 28, 29]

# %% [markdown]
# ### Define the number of scenarios and Monte Carlo runs

# %%
n_scenarios = 200 # Number of scenarios
n_runs_per_scenario = 500  # Monte Carlo runs per scenario
scenario_results = []
# Define the variation range with the original mean and standard deviation values of the static generators' output of the PV buses
mean_variation = 1
std_variation =0.5
# Define variation range for line distances by introducing different distances between the variables
line_length_variation = 0.2  # ±20% variation

# %% [markdown]
# ### Run different scenarios using the different mean and standard deviation of static generator(solar injection) outputs, Along with varying grid network topologies

# %%
# Generate Scenarios Record: static generator means(solar-based generation) for the solar generator buses
for scenario in range(n_scenarios):
    
    scenario_lolps = []  # Store LOLP for each run in this scenario
    print(f"Running Scenario {scenario + 1}/{n_scenarios}")   
    lolp_count = 0  # To count the number of load losses
    
    #Add solar generation variation to the static generators of the PV buses
    scenario_means = [
    max(1e-6, 2.5* solar_mean_per_sgen * (1 + np.random.uniform(-mean_variation, mean_variation)))
    for _ in range(n)
]
    scenario_stds = [
    max(1e-6, solar_std_per_sgen * (1 + np.random.uniform(-std_variation, std_variation)))
    for _ in range(n)
]
    
    # Record factors
    sgen_output_per_pv_bus = {bus: [] for bus in solar_sgen_buses}
    total_solar_generation = []
    total_generation = []
    total_reactive_power = []
    voltage_deviations = []
    
    # Record phase angles and generator voltages per bus
    # phase_angles_per_scenario = {bus: [] for bus in gen_buses}
    # generator_voltages_per_scenario = {bus: [] for bus in gen_buses}
    
    # Vary the length of the line impedances to simulate different grid topologies (different distance configuration）
    net.line['length_km'] = net.line['length_km'] * (1 + np.random.uniform(-line_length_variation, line_length_variation, size=len(net.line)))
    
    # Run power flow to update network parameters
    pp.runpp(net)

    # Compute updated Z-matrix
    Ybus, _, _ = makeYbus(net._ppc["baseMVA"], net._ppc["bus"], net._ppc["branch"])
    Zbus = np.linalg.inv(Ybus.toarray())

    gen_buses = net.gen["bus"].values
    load_buses = net.load["bus"].values

    gen_to_gen = compute_distances(gen_buses, gen_buses, Zbus)
    load_to_load = compute_distances(load_buses, load_buses, Zbus)
    gen_to_load = compute_distances(gen_buses, load_buses, Zbus)

    df_gen_to_gen = pd.DataFrame(gen_to_gen, columns=["Gen Bus 1", "Gen Bus 2", "Impedance"])
    df_load_to_load = pd.DataFrame(load_to_load, columns=["Load Bus 1", "Load Bus 2", "Impedance"])
    df_gen_to_load = pd.DataFrame(gen_to_load, columns=["Gen Bus", "Load Bus", "Impedance"])

    shortest_gen_to_gen = df_gen_to_gen.loc[df_gen_to_gen["Impedance"].idxmin()]
    longest_gen_to_gen = df_gen_to_gen.loc[df_gen_to_gen["Impedance"].idxmax()]
    shortest_load_to_load = df_load_to_load.loc[df_load_to_load["Impedance"].idxmin()]
    longest_load_to_load = df_load_to_load.loc[df_load_to_load["Impedance"].idxmax()]
    shortest_gen_to_load = df_gen_to_load.loc[df_gen_to_load["Impedance"].idxmin()]
    longest_gen_to_load = df_gen_to_load.loc[df_gen_to_load["Impedance"].idxmax()]

    for run in range(n_runs_per_scenario):
        # Sample static generator(solar) outputs from the normal distribution
        pv_outputs = [max(0, np.random.normal(mean, std)) for mean, std in zip(scenario_means, scenario_stds)]
        
        # Update solar generation with each static generator in the network
        for i, bus in enumerate(solar_sgen_buses):
             p_output = min(pv_outputs[i], total_drop_conventional_capacity/n) # Ensure the injected active power does not exceed the capacity limit
             q_output =  p_output * np.tan(np.arccos(power_factor))  # Adjust Q dynamically based on the constant power factor
             net.sgen.loc[net.sgen['bus'] == bus, ['p_mw', 'q_mvar']] = [p_output, q_output]
        
        try:
            # Run Power flow
            pp.runpp(net)
            
            # # Store Phase Angles for all Buses
            # for bus in gen_buses:
            #     phase_angles_per_scenario[bus].append(net.res_bus.at[bus, 'va_degree'])

            # # Store Voltage Magnitudes for all Buses
            # for bus in gen_buses:
            #     generator_voltages_per_scenario[bus].append(net.res_bus.at[bus, 'vm_pu'])
                
            # Store solar generation with static generator 
            for i, bus in enumerate(solar_sgen_buses):
               output = net.res_sgen.loc[net.sgen['bus'] == bus, 'p_mw'].values
               if len(output) > 0:
                  sgen_output_per_pv_bus[bus].append(output[0])   
                   
            # Store other factors
            total_generation = net.res_sgen['p_mw'].sum() + net.res_gen['p_mw'].sum()
            total_solar_generation.append(net.res_sgen['p_mw'].sum())
            total_reactive_power.append(net.res_bus['q_mvar'].sum())
            
            # Calculate voltage deviation from 1.0 p.u.
            voltage_dev = abs(net.res_bus['vm_pu'] - 1).mean()
            voltage_deviations.append(voltage_dev)
            
            # Calculate LOLP
            total_load = net.load['p_mw'].sum()
            lolp = 1 if total_generation < total_load else 0  # Load loss if generation < load
            scenario_lolps.append(lolp)
        except pp.LoadflowNotConverged:
            print(f"Power flow did not converge for scenario {scenario}, run {run}.")
            continue
            
   # Calculate the static generator active power means for the solar generator buses
    avg_sgen_per_solar_bus = {
           bus: np.mean(outputs) if len(outputs) > 0 else 0
           for bus, outputs in sgen_output_per_pv_bus.items()
     }
    
    # Calculate the average LOLP value for this scenario
    avg_lolp = np.mean(scenario_lolps) if scenario_lolps else None
    print(f"Scenario {scenario + 1}: Average LOLP = {avg_lolp}")
    # Record other potential factors' value
    avg_solar_generation = np.mean(total_solar_generation)
    avg_generation = np.mean(total_generation)
    avg_reactive_power = np.mean(total_reactive_power)
    avg_voltage_deviation = np.mean(voltage_deviations)
    
    #Phase Angles and Voltages
    # avg_phase_angles = {bus: np.mean(angles) for bus, angles in phase_angles_per_scenario.items()}
    # avg_generator_voltages = {bus: np.mean(voltages) for bus, voltages in generator_voltages_per_scenario.items()}
    
    # Calculate LOLP for this scenario
    # lolp = lolp_count / n_runs_per_scenario
    # solar_sgen_buses= [3, 4, 6, 10, 12, 14, 16, 19] 
    scenario_results.append({
        'Scenario': scenario + 1,
        'Sgen1_ Mean_Solar Output': avg_sgen_per_solar_bus[3],
        'Sgen2_ Mean_Solar Output': avg_sgen_per_solar_bus[4],
        'Sgen3_ Mean_Solar Output': avg_sgen_per_solar_bus[6],
        'Sgen4_ Mean_Solar Output': avg_sgen_per_solar_bus[10],
        'Sgen5_ Mean_Solar Output': avg_sgen_per_solar_bus[12],
        'Sgen6_ Mean_Solar Output': avg_sgen_per_solar_bus[14],
        'Sgen7_ Mean_Solar Output': avg_sgen_per_solar_bus[16],
        'Sgen8_ Mean_Solar Output': avg_sgen_per_solar_bus[19],
        'Shortest Gen-to-Gen Impedance': shortest_gen_to_gen["Impedance"],
        'Longest Gen-to-Gen Impedance': longest_gen_to_gen["Impedance"],
        'Shortest Load-to-Load Impedance': shortest_load_to_load["Impedance"],
        'Longest Load-to-Load Impedance': longest_load_to_load["Impedance"],
        'Shortest Gen-to-Load Impedance': shortest_gen_to_load["Impedance"],
        'Longest Gen-to-Load Impedance': longest_gen_to_load["Impedance"],
        'Total Solar Generation': avg_solar_generation,
        'Total Generation': avg_generation,
        'Voltage Deviation': avg_voltage_deviation,
         #'Phase Angles PV': avg_phase_angles,
         #'Generator Voltages': avg_generator_voltages,
        'LOLP': avg_lolp
    })

# Save results to a DataFrame
df_scenario_results = pd.DataFrame(scenario_results)
df_scenario_results.to_excel("Causal_reliability_Results1.xlsx", index=False)
print("Scenario results saved to 'Causal_reliability_Results1.xlsx'.")
# Out:
# Running Scenario 1/200
# Scenario 1: Average LOLP = 0.396
# Running Scenario 2/200
# Scenario 2: Average LOLP = 0.484
# Running Scenario 3/200
# Scenario 3: Average LOLP = 0.1
# Running Scenario 4/200
# Scenario 4: Average LOLP = 0.84
# Running Scenario 5/200
# Scenario 5: Average LOLP = 0.046
# Running Scenario 6/200
# Scenario 6: Average LOLP = 0.522
# Running Scenario 7/200
# Scenario 7: Average LOLP = 0.472
# Running Scenario 8/200
# Scenario 8: Average LOLP = 0.016
# Running Scenario 9/200
# Scenario 9: Average LOLP = 0.898
# Running Scenario 10/200
# Scenario 10: Average LOLP = 0.044
# Running Scenario 11/200
# Scenario 11: Average LOLP = 0.178
# Running Scenario 12/200
# Scenario 12: Average LOLP = 0.106
# Running Scenario 13/200
# Scenario 13: Average LOLP = 0.18
# Running Scenario 14/200
# Scenario 14: Average LOLP = 0.02
# Running Scenario 15/200
# Scenario 15: Average LOLP = 0.162
# Running Scenario 16/200
# Scenario 16: Average LOLP = 0.966
# Running Scenario 17/200
# Scenario 17: Average LOLP = 0.34
# Running Scenario 18/200
# Scenario 18: Average LOLP = 0.63
# Running Scenario 19/200
# Scenario 19: Average LOLP = 0.038
# Running Scenario 20/200
# Scenario 20: Average LOLP = 0.364
# Running Scenario 21/200
# Scenario 21: Average LOLP = 0.34
# Running Scenario 22/200
# Scenario 22: Average LOLP = 0.616
# Running Scenario 23/200
# Scenario 23: Average LOLP = 0.68
# Running Scenario 24/200
# Scenario 24: Average LOLP = 0.038
# Running Scenario 25/200
# Scenario 25: Average LOLP = 0.19
# Running Scenario 26/200
# Scenario 26: Average LOLP = 0.446
# Running Scenario 27/200
# Scenario 27: Average LOLP = 0.05
# Running Scenario 28/200
# Scenario 28: Average LOLP = 0.888
# Running Scenario 29/200
# Scenario 29: Average LOLP = 0.53
# Running Scenario 30/200
# Scenario 30: Average LOLP = 0.134
# Running Scenario 31/200
# Scenario 31: Average LOLP = 0.726
# Running Scenario 32/200
# Scenario 32: Average LOLP = 0.574
# Running Scenario 33/200
# Scenario 33: Average LOLP = 0.012
# Running Scenario 34/200
# Scenario 34: Average LOLP = 0.634
# Running Scenario 35/200
# Scenario 35: Average LOLP = 0.97
# Running Scenario 36/200
# Scenario 36: Average LOLP = 0.994
# Running Scenario 37/200
# Scenario 37: Average LOLP = 0.582
# Running Scenario 38/200
# Scenario 38: Average LOLP = 0.204
# Running Scenario 39/200
# Scenario 39: Average LOLP = 0.202
# Running Scenario 40/200
# Scenario 40: Average LOLP = 0.318
# Running Scenario 41/200
# Scenario 41: Average LOLP = 0.004
# Running Scenario 42/200
# Scenario 42: Average LOLP = 0.66
# Running Scenario 43/200
# Scenario 43: Average LOLP = 0.346
# Running Scenario 44/200
# Scenario 44: Average LOLP = 0.9
# Running Scenario 45/200
# Scenario 45: Average LOLP = 0.156
# Running Scenario 46/200
# Scenario 46: Average LOLP = 0.006
# Running Scenario 47/200
# Scenario 47: Average LOLP = 0.726
# Running Scenario 48/200
# Scenario 48: Average LOLP = 0.542
# Running Scenario 49/200
# Scenario 49: Average LOLP = 0.566
# Running Scenario 50/200
# Scenario 50: Average LOLP = 0.93
# Running Scenario 51/200
# Scenario 51: Average LOLP = 0.998
# Running Scenario 52/200
# Scenario 52: Average LOLP = 0.696
# Running Scenario 53/200
# Scenario 53: Average LOLP = 0.008
# Running Scenario 54/200
# Scenario 54: Average LOLP = 0.782
# Running Scenario 55/200
# Scenario 55: Average LOLP = 0.684
# Running Scenario 56/200
# Scenario 56: Average LOLP = 0.638
# Running Scenario 57/200
# Scenario 57: Average LOLP = 0.012
# Running Scenario 58/200
# Scenario 58: Average LOLP = 0.098
# Running Scenario 59/200
# Scenario 59: Average LOLP = 0.034
# Running Scenario 60/200
# Scenario 60: Average LOLP = 0.674
# Running Scenario 61/200
# Scenario 61: Average LOLP = 0.706
# Running Scenario 62/200
# Scenario 62: Average LOLP = 0.762
# Running Scenario 63/200
# Scenario 63: Average LOLP = 0.428
# Running Scenario 64/200
# Scenario 64: Average LOLP = 0.77
# Running Scenario 65/200
# Scenario 65: Average LOLP = 0.43
# Running Scenario 66/200
# Scenario 66: Average LOLP = 0.014
# Running Scenario 67/200
# Scenario 67: Average LOLP = 0.32
# Running Scenario 68/200
# Scenario 68: Average LOLP = 0.398
# Running Scenario 69/200
# Scenario 69: Average LOLP = 0.892
# Running Scenario 70/200
# Scenario 70: Average LOLP = 0.07
# Running Scenario 71/200
# Scenario 71: Average LOLP = 0.034
# Running Scenario 72/200
# Scenario 72: Average LOLP = 0.404
# Running Scenario 73/200
# Scenario 73: Average LOLP = 0.014
# Running Scenario 74/200
# Scenario 74: Average LOLP = 0.08
# Running Scenario 75/200
# Scenario 75: Average LOLP = 0.028
# Running Scenario 76/200
# Scenario 76: Average LOLP = 0.086
# Running Scenario 77/200
# Scenario 77: Average LOLP = 0.0
# Running Scenario 78/200
# Scenario 78: Average LOLP = 0.478
# Running Scenario 79/200
# Scenario 79: Average LOLP = 0.244
# Running Scenario 80/200
# Scenario 80: Average LOLP = 0.786
# Running Scenario 81/200
# Scenario 81: Average LOLP = 0.044
# Running Scenario 82/200
# Scenario 82: Average LOLP = 0.088
# Running Scenario 83/200
# Scenario 83: Average LOLP = 0.0
# Running Scenario 84/200
# Scenario 84: Average LOLP = 0.002
# Running Scenario 85/200
# Scenario 85: Average LOLP = 0.336
# Running Scenario 86/200
# Scenario 86: Average LOLP = 0.87
# Running Scenario 87/200
# Scenario 87: Average LOLP = 0.3
# Running Scenario 88/200
# Scenario 88: Average LOLP = 0.982
# Running Scenario 89/200
# Scenario 89: Average LOLP = 0.308
# Running Scenario 90/200
# Scenario 90: Average LOLP = 0.968
# Running Scenario 91/200
# Scenario 91: Average LOLP = 0.216
# Running Scenario 92/200
# Scenario 92: Average LOLP = 0.0
# Running Scenario 93/200
# Scenario 93: Average LOLP = 0.186
# Running Scenario 94/200
# Scenario 94: Average LOLP = 0.814
# Running Scenario 95/200
# Scenario 95: Average LOLP = 0.466
# Running Scenario 96/200
# Scenario 96: Average LOLP = 0.7
# Running Scenario 97/200
# Scenario 97: Average LOLP = 0.0
# Running Scenario 98/200
# Scenario 98: Average LOLP = 0.412
# Running Scenario 99/200
# Scenario 99: Average LOLP = 0.566
# Running Scenario 100/200
# Scenario 100: Average LOLP = 0.636
# Running Scenario 101/200
# Scenario 101: Average LOLP = 0.088
# Running Scenario 102/200
# Scenario 102: Average LOLP = 0.178
# Running Scenario 103/200
# Scenario 103: Average LOLP = 0.066
# Running Scenario 104/200
# Scenario 104: Average LOLP = 0.806
# Running Scenario 105/200
# Scenario 105: Average LOLP = 0.344
# Running Scenario 106/200
# Scenario 106: Average LOLP = 0.466
# Running Scenario 107/200
# Scenario 107: Average LOLP = 0.28
# Running Scenario 108/200
# Scenario 108: Average LOLP = 0.02
# Running Scenario 109/200
# Scenario 109: Average LOLP = 0.058
# Running Scenario 110/200
# Scenario 110: Average LOLP = 0.988
# Running Scenario 111/200
# Scenario 111: Average LOLP = 0.026
# Running Scenario 112/200
# Scenario 112: Average LOLP = 0.206
# Running Scenario 113/200
# Scenario 113: Average LOLP = 0.872
# Running Scenario 114/200
# Scenario 114: Average LOLP = 0.634
# Running Scenario 115/200
# Scenario 115: Average LOLP = 0.574
# Running Scenario 116/200
# Scenario 116: Average LOLP = 0.776
# Running Scenario 117/200
# Scenario 117: Average LOLP = 0.82
# Running Scenario 118/200
# Scenario 118: Average LOLP = 0.006
# Running Scenario 119/200
# Scenario 119: Average LOLP = 0.998
# Running Scenario 120/200
# Scenario 120: Average LOLP = 0.862
# Running Scenario 121/200
# Scenario 121: Average LOLP = 0.056
# Running Scenario 122/200
# Scenario 122: Average LOLP = 0.25
# Running Scenario 123/200
# Scenario 123: Average LOLP = 0.94
# Running Scenario 124/200
# Scenario 124: Average LOLP = 0.0
# Running Scenario 125/200
# Scenario 125: Average LOLP = 0.096
# Running Scenario 126/200
# Scenario 126: Average LOLP = 0.126
# Running Scenario 127/200
# Scenario 127: Average LOLP = 1.0
# Running Scenario 128/200
# Scenario 128: Average LOLP = 0.446
# Running Scenario 129/200
# Scenario 129: Average LOLP = 0.368
# Running Scenario 130/200
# Scenario 130: Average LOLP = 0.122
# Running Scenario 131/200
# Scenario 131: Average LOLP = 0.652
# Running Scenario 132/200
# Scenario 132: Average LOLP = 0.496
# Running Scenario 133/200
# Scenario 133: Average LOLP = 0.464
# Running Scenario 134/200
# Scenario 134: Average LOLP = 0.8
# Running Scenario 135/200
# Scenario 135: Average LOLP = 0.294
# Running Scenario 136/200
# Scenario 136: Average LOLP = 0.232
# Running Scenario 137/200
# Scenario 137: Average LOLP = 0.244
# Running Scenario 138/200
# Scenario 138: Average LOLP = 0.034
# Running Scenario 139/200
# Scenario 139: Average LOLP = 0.832
# Running Scenario 140/200
# Scenario 140: Average LOLP = 0.274
# Running Scenario 141/200
# Scenario 141: Average LOLP = 0.07
# Running Scenario 142/200
# Scenario 142: Average LOLP = 0.812
# Running Scenario 143/200
# Scenario 143: Average LOLP = 0.92
# Running Scenario 144/200
# Scenario 144: Average LOLP = 0.19
# Running Scenario 145/200
# Scenario 145: Average LOLP = 0.994
# Running Scenario 146/200
# Scenario 146: Average LOLP = 0.784
# Running Scenario 147/200
# Scenario 147: Average LOLP = 0.946
# Running Scenario 148/200
# Scenario 148: Average LOLP = 0.244
# Running Scenario 149/200
# Scenario 149: Average LOLP = 0.426
# Running Scenario 150/200
# Scenario 150: Average LOLP = 0.708
# Running Scenario 151/200
# Scenario 151: Average LOLP = 0.408
# Running Scenario 152/200
# Scenario 152: Average LOLP = 0.094
# Running Scenario 153/200
# Scenario 153: Average LOLP = 0.824
# Running Scenario 154/200
# Scenario 154: Average LOLP = 0.332
# Running Scenario 155/200
# Scenario 155: Average LOLP = 0.472
# Running Scenario 156/200
# Scenario 156: Average LOLP = 0.962
# Running Scenario 157/200
# Scenario 157: Average LOLP = 0.968
# Running Scenario 158/200
# Scenario 158: Average LOLP = 0.27
# Running Scenario 159/200
# Power flow did not converge for scenario 158, run 95.
# Power flow did not converge for scenario 158, run 105.
# Power flow did not converge for scenario 158, run 308.
# Scenario 159: Average LOLP = 0.9275653923541247
# Running Scenario 160/200
# Scenario 160: Average LOLP = 0.008
# Running Scenario 161/200
# Scenario 161: Average LOLP = 0.982
# Running Scenario 162/200
# Scenario 162: Average LOLP = 0.002
# Running Scenario 163/200
# Power flow did not converge for scenario 162, run 327.
# Power flow did not converge for scenario 162, run 482.
# Scenario 163: Average LOLP = 0.4839357429718876
# Running Scenario 164/200
# Scenario 164: Average LOLP = 1.0
# Running Scenario 165/200
# Scenario 165: Average LOLP = 0.562
# Running Scenario 166/200
# Scenario 166: Average LOLP = 0.77
# Running Scenario 167/200
# Scenario 167: Average LOLP = 0.544
# Running Scenario 168/200
# Scenario 168: Average LOLP = 0.942
# Running Scenario 169/200
# Scenario 169: Average LOLP = 0.384
# Running Scenario 170/200
# Power flow did not converge for scenario 169, run 164.
# Scenario 170: Average LOLP = 0.27655310621242485
# Running Scenario 171/200
# Power flow did not converge for scenario 170, run 16.
# Power flow did not converge for scenario 170, run 88.
# Power flow did not converge for scenario 170, run 150.
# Power flow did not converge for scenario 170, run 177.
# Power flow did not converge for scenario 170, run 443.
# Scenario 171: Average LOLP = 0.7757575757575758
# Running Scenario 172/200
# Power flow did not converge for scenario 171, run 48.
# Power flow did not converge for scenario 171, run 230.
# Power flow did not converge for scenario 171, run 367.
# Scenario 172: Average LOLP = 0.7766599597585513
# Running Scenario 173/200
# Power flow did not converge for scenario 172, run 3.
# Power flow did not converge for scenario 172, run 7.
# Power flow did not converge for scenario 172, run 15.
# Power flow did not converge for scenario 172, run 28.
# Power flow did not converge for scenario 172, run 33.
# Power flow did not converge for scenario 172, run 45.
# Power flow did not converge for scenario 172, run 48.
# Power flow did not converge for scenario 172, run 55.
# Power flow did not converge for scenario 172, run 56.
# Power flow did not converge for scenario 172, run 58.
# Power flow did not converge for scenario 172, run 60.
# Power flow did not converge for scenario 172, run 64.
# Power flow did not converge for scenario 172, run 65.
# Power flow did not converge for scenario 172, run 68.
# Power flow did not converge for scenario 172, run 71.
# Power flow did not converge for scenario 172, run 73.
# Power flow did not converge for scenario 172, run 75.
# Power flow did not converge for scenario 172, run 77.
# Power flow did not converge for scenario 172, run 79.
# Power flow did not converge for scenario 172, run 81.
# Power flow did not converge for scenario 172, run 84.
# Power flow did not converge for scenario 172, run 86.
# Power flow did not converge for scenario 172, run 87.
# Power flow did not converge for scenario 172, run 89.
# Power flow did not converge for scenario 172, run 93.
# Power flow did not converge for scenario 172, run 98.
# Power flow did not converge for scenario 172, run 101.
# Power flow did not converge for scenario 172, run 102.
# Power flow did not converge for scenario 172, run 109.
# Power flow did not converge for scenario 172, run 116.
# Power flow did not converge for scenario 172, run 117.
# Power flow did not converge for scenario 172, run 118.
# Power flow did not converge for scenario 172, run 119.
# Power flow did not converge for scenario 172, run 127.
# Power flow did not converge for scenario 172, run 133.
# Power flow did not converge for scenario 172, run 134.
# Power flow did not converge for scenario 172, run 137.
# Power flow did not converge for scenario 172, run 141.
# Power flow did not converge for scenario 172, run 142.
# Power flow did not converge for scenario 172, run 145.
# Power flow did not converge for scenario 172, run 148.
# Power flow did not converge for scenario 172, run 153.
# Power flow did not converge for scenario 172, run 157.
# Power flow did not converge for scenario 172, run 160.
# Power flow did not converge for scenario 172, run 167.
# Power flow did not converge for scenario 172, run 170.
# Power flow did not converge for scenario 172, run 176.
# Power flow did not converge for scenario 172, run 181.
# Power flow did not converge for scenario 172, run 183.
# Power flow did not converge for scenario 172, run 184.
# Power flow did not converge for scenario 172, run 185.
# Power flow did not converge for scenario 172, run 186.
# Power flow did not converge for scenario 172, run 189.
# Power flow did not converge for scenario 172, run 192.
# Power flow did not converge for scenario 172, run 199.
# Power flow did not converge for scenario 172, run 200.
# Power flow did not converge for scenario 172, run 208.
# Power flow did not converge for scenario 172, run 210.
# Power flow did not converge for scenario 172, run 213.
# Power flow did not converge for scenario 172, run 221.
# Power flow did not converge for scenario 172, run 225.
# Power flow did not converge for scenario 172, run 226.
# Power flow did not converge for scenario 172, run 234.
# Power flow did not converge for scenario 172, run 235.
# Power flow did not converge for scenario 172, run 236.
# Power flow did not converge for scenario 172, run 239.
# Power flow did not converge for scenario 172, run 245.
# Power flow did not converge for scenario 172, run 250.
# Power flow did not converge for scenario 172, run 252.
# Power flow did not converge for scenario 172, run 257.
# Power flow did not converge for scenario 172, run 271.
# Power flow did not converge for scenario 172, run 277.
# Power flow did not converge for scenario 172, run 278.
# Power flow did not converge for scenario 172, run 287.
# Power flow did not converge for scenario 172, run 290.
# Power flow did not converge for scenario 172, run 293.
# Power flow did not converge for scenario 172, run 294.
# Power flow did not converge for scenario 172, run 302.
# Power flow did not converge for scenario 172, run 304.
# Power flow did not converge for scenario 172, run 307.
# Power flow did not converge for scenario 172, run 309.
# Power flow did not converge for scenario 172, run 316.
# Power flow did not converge for scenario 172, run 318.
# Power flow did not converge for scenario 172, run 320.
# Power flow did not converge for scenario 172, run 324.
# Power flow did not converge for scenario 172, run 330.
# Power flow did not converge for scenario 172, run 333.
# Power flow did not converge for scenario 172, run 334.
# Power flow did not converge for scenario 172, run 335.
# Power flow did not converge for scenario 172, run 344.
# Power flow did not converge for scenario 172, run 345.
# Power flow did not converge for scenario 172, run 350.
# Power flow did not converge for scenario 172, run 357.
# Power flow did not converge for scenario 172, run 359.
# Power flow did not converge for scenario 172, run 362.
# Power flow did not converge for scenario 172, run 365.
# Power flow did not converge for scenario 172, run 367.
# Power flow did not converge for scenario 172, run 368.
# Power flow did not converge for scenario 172, run 380.
# Power flow did not converge for scenario 172, run 382.
# Power flow did not converge for scenario 172, run 387.
# Power flow did not converge for scenario 172, run 388.
# Power flow did not converge for scenario 172, run 389.
# Power flow did not converge for scenario 172, run 390.
# Power flow did not converge for scenario 172, run 401.
# Power flow did not converge for scenario 172, run 405.
# Power flow did not converge for scenario 172, run 413.
# Power flow did not converge for scenario 172, run 416.
# Power flow did not converge for scenario 172, run 419.
# Power flow did not converge for scenario 172, run 420.
# Power flow did not converge for scenario 172, run 424.
# Power flow did not converge for scenario 172, run 426.
# Power flow did not converge for scenario 172, run 429.
# Power flow did not converge for scenario 172, run 434.
# Power flow did not converge for scenario 172, run 437.
# Power flow did not converge for scenario 172, run 438.
# Power flow did not converge for scenario 172, run 439.
# Power flow did not converge for scenario 172, run 442.
# Power flow did not converge for scenario 172, run 449.
# Power flow did not converge for scenario 172, run 453.
# Power flow did not converge for scenario 172, run 457.
# Power flow did not converge for scenario 172, run 462.
# Power flow did not converge for scenario 172, run 465.
# Power flow did not converge for scenario 172, run 471.
# Power flow did not converge for scenario 172, run 474.
# Power flow did not converge for scenario 172, run 477.
# Power flow did not converge for scenario 172, run 480.
# Power flow did not converge for scenario 172, run 484.
# Power flow did not converge for scenario 172, run 486.
# Power flow did not converge for scenario 172, run 494.
# Power flow did not converge for scenario 172, run 496.
# Power flow did not converge for scenario 172, run 498.
# Scenario 173: Average LOLP = 0.125
# Running Scenario 174/200
# Power flow did not converge for scenario 173, run 4.
# Power flow did not converge for scenario 173, run 5.
# Power flow did not converge for scenario 173, run 12.
# Power flow did not converge for scenario 173, run 19.
# Power flow did not converge for scenario 173, run 25.
# Power flow did not converge for scenario 173, run 35.
# Power flow did not converge for scenario 173, run 46.
# Power flow did not converge for scenario 173, run 47.
# Power flow did not converge for scenario 173, run 48.
# Power flow did not converge for scenario 173, run 49.
# Power flow did not converge for scenario 173, run 51.
# Power flow did not converge for scenario 173, run 54.
# Power flow did not converge for scenario 173, run 55.
# Power flow did not converge for scenario 173, run 59.
# Power flow did not converge for scenario 173, run 62.
# Power flow did not converge for scenario 173, run 63.
# Power flow did not converge for scenario 173, run 65.
# Power flow did not converge for scenario 173, run 74.
# Power flow did not converge for scenario 173, run 75.
# Power flow did not converge for scenario 173, run 76.
# Power flow did not converge for scenario 173, run 81.
# Power flow did not converge for scenario 173, run 85.
# Power flow did not converge for scenario 173, run 89.
# Power flow did not converge for scenario 173, run 94.
# Power flow did not converge for scenario 173, run 100.
# Power flow did not converge for scenario 173, run 110.
# Power flow did not converge for scenario 173, run 114.
# Power flow did not converge for scenario 173, run 121.
# Power flow did not converge for scenario 173, run 122.
# Power flow did not converge for scenario 173, run 126.
# Power flow did not converge for scenario 173, run 133.
# Power flow did not converge for scenario 173, run 136.
# Power flow did not converge for scenario 173, run 141.
# Power flow did not converge for scenario 173, run 145.
# Power flow did not converge for scenario 173, run 151.
# Power flow did not converge for scenario 173, run 152.
# Power flow did not converge for scenario 173, run 155.
# Power flow did not converge for scenario 173, run 160.
# Power flow did not converge for scenario 173, run 164.
# Power flow did not converge for scenario 173, run 182.
# Power flow did not converge for scenario 173, run 186.
# Power flow did not converge for scenario 173, run 195.
# Power flow did not converge for scenario 173, run 203.
# Power flow did not converge for scenario 173, run 204.
# Power flow did not converge for scenario 173, run 210.
# Power flow did not converge for scenario 173, run 211.
# Power flow did not converge for scenario 173, run 219.
# Power flow did not converge for scenario 173, run 222.
# Power flow did not converge for scenario 173, run 243.
# Power flow did not converge for scenario 173, run 244.
# Power flow did not converge for scenario 173, run 247.
# Power flow did not converge for scenario 173, run 250.
# Power flow did not converge for scenario 173, run 252.
# Power flow did not converge for scenario 173, run 255.
# Power flow did not converge for scenario 173, run 270.
# Power flow did not converge for scenario 173, run 271.
# Power flow did not converge for scenario 173, run 276.
# Power flow did not converge for scenario 173, run 281.
# Power flow did not converge for scenario 173, run 283.
# Power flow did not converge for scenario 173, run 285.
# Power flow did not converge for scenario 173, run 292.
# Power flow did not converge for scenario 173, run 294.
# Power flow did not converge for scenario 173, run 296.
# Power flow did not converge for scenario 173, run 297.
# Power flow did not converge for scenario 173, run 305.
# Power flow did not converge for scenario 173, run 307.
# Power flow did not converge for scenario 173, run 317.
# Power flow did not converge for scenario 173, run 319.
# Power flow did not converge for scenario 173, run 321.
# Power flow did not converge for scenario 173, run 324.
# Power flow did not converge for scenario 173, run 329.
# Power flow did not converge for scenario 173, run 341.
# Power flow did not converge for scenario 173, run 346.
# Power flow did not converge for scenario 173, run 357.
# Power flow did not converge for scenario 173, run 359.
# Power flow did not converge for scenario 173, run 365.
# Power flow did not converge for scenario 173, run 375.
# Power flow did not converge for scenario 173, run 376.
# Power flow did not converge for scenario 173, run 386.
# Power flow did not converge for scenario 173, run 388.
# Power flow did not converge for scenario 173, run 389.
# Power flow did not converge for scenario 173, run 397.
# Power flow did not converge for scenario 173, run 400.
# Power flow did not converge for scenario 173, run 401.
# Power flow did not converge for scenario 173, run 410.
# Power flow did not converge for scenario 173, run 415.
# Power flow did not converge for scenario 173, run 418.
# Power flow did not converge for scenario 173, run 419.
# Power flow did not converge for scenario 173, run 422.
# Power flow did not converge for scenario 173, run 424.
# Power flow did not converge for scenario 173, run 429.
# Power flow did not converge for scenario 173, run 432.
# Power flow did not converge for scenario 173, run 435.
# Power flow did not converge for scenario 173, run 439.
# Power flow did not converge for scenario 173, run 445.
# Power flow did not converge for scenario 173, run 448.
# Power flow did not converge for scenario 173, run 451.
# Power flow did not converge for scenario 173, run 453.
# Power flow did not converge for scenario 173, run 459.
# Power flow did not converge for scenario 173, run 463.
# Power flow did not converge for scenario 173, run 467.
# Power flow did not converge for scenario 173, run 485.
# Power flow did not converge for scenario 173, run 493.
# Power flow did not converge for scenario 173, run 497.
# Scenario 174: Average LOLP = 0.5934343434343434
# Running Scenario 175/200
# Power flow did not converge for scenario 174, run 1.
# Power flow did not converge for scenario 174, run 2.
# Power flow did not converge for scenario 174, run 3.
# Power flow did not converge for scenario 174, run 7.
# Power flow did not converge for scenario 174, run 9.
# Power flow did not converge for scenario 174, run 11.
# Power flow did not converge for scenario 174, run 12.
# Power flow did not converge for scenario 174, run 13.
# Power flow did not converge for scenario 174, run 17.
# Power flow did not converge for scenario 174, run 18.
# Power flow did not converge for scenario 174, run 30.
# Power flow did not converge for scenario 174, run 31.
# Power flow did not converge for scenario 174, run 39.
# Power flow did not converge for scenario 174, run 44.
# Power flow did not converge for scenario 174, run 47.
# Power flow did not converge for scenario 174, run 51.
# Power flow did not converge for scenario 174, run 55.
# Power flow did not converge for scenario 174, run 60.
# Power flow did not converge for scenario 174, run 64.
# Power flow did not converge for scenario 174, run 70.
# Power flow did not converge for scenario 174, run 78.
# Power flow did not converge for scenario 174, run 79.
# Power flow did not converge for scenario 174, run 84.
# Power flow did not converge for scenario 174, run 88.
# Power flow did not converge for scenario 174, run 92.
# Power flow did not converge for scenario 174, run 95.
# Power flow did not converge for scenario 174, run 97.
# Power flow did not converge for scenario 174, run 101.
# Power flow did not converge for scenario 174, run 103.
# Power flow did not converge for scenario 174, run 104.
# Power flow did not converge for scenario 174, run 124.
# Power flow did not converge for scenario 174, run 132.
# Power flow did not converge for scenario 174, run 138.
# Power flow did not converge for scenario 174, run 143.
# Power flow did not converge for scenario 174, run 149.
# Power flow did not converge for scenario 174, run 152.
# Power flow did not converge for scenario 174, run 155.
# Power flow did not converge for scenario 174, run 157.
# Power flow did not converge for scenario 174, run 161.
# Power flow did not converge for scenario 174, run 167.
# Power flow did not converge for scenario 174, run 171.
# Power flow did not converge for scenario 174, run 174.
# Power flow did not converge for scenario 174, run 178.
# Power flow did not converge for scenario 174, run 179.
# Power flow did not converge for scenario 174, run 182.
# Power flow did not converge for scenario 174, run 184.
# Power flow did not converge for scenario 174, run 186.
# Power flow did not converge for scenario 174, run 188.
# Power flow did not converge for scenario 174, run 198.
# Power flow did not converge for scenario 174, run 200.
# Power flow did not converge for scenario 174, run 201.
# Power flow did not converge for scenario 174, run 205.
# Power flow did not converge for scenario 174, run 207.
# Power flow did not converge for scenario 174, run 211.
# Power flow did not converge for scenario 174, run 214.
# Power flow did not converge for scenario 174, run 215.
# Power flow did not converge for scenario 174, run 216.
# Power flow did not converge for scenario 174, run 217.
# Power flow did not converge for scenario 174, run 221.
# Power flow did not converge for scenario 174, run 224.
# Power flow did not converge for scenario 174, run 227.
# Power flow did not converge for scenario 174, run 239.
# Power flow did not converge for scenario 174, run 241.
# Power flow did not converge for scenario 174, run 242.
# Power flow did not converge for scenario 174, run 243.
# Power flow did not converge for scenario 174, run 246.
# Power flow did not converge for scenario 174, run 250.
# Power flow did not converge for scenario 174, run 254.
# Power flow did not converge for scenario 174, run 256.
# Power flow did not converge for scenario 174, run 260.
# Power flow did not converge for scenario 174, run 262.
# Power flow did not converge for scenario 174, run 265.
# Power flow did not converge for scenario 174, run 270.
# Power flow did not converge for scenario 174, run 271.
# Power flow did not converge for scenario 174, run 276.
# Power flow did not converge for scenario 174, run 283.
# Power flow did not converge for scenario 174, run 292.
# Power flow did not converge for scenario 174, run 299.
# Power flow did not converge for scenario 174, run 300.
# Power flow did not converge for scenario 174, run 302.
# Power flow did not converge for scenario 174, run 303.
# Power flow did not converge for scenario 174, run 306.
# Power flow did not converge for scenario 174, run 309.
# Power flow did not converge for scenario 174, run 317.
# Power flow did not converge for scenario 174, run 324.
# Power flow did not converge for scenario 174, run 329.
# Power flow did not converge for scenario 174, run 333.
# Power flow did not converge for scenario 174, run 336.
# Power flow did not converge for scenario 174, run 341.
# Power flow did not converge for scenario 174, run 343.
# Power flow did not converge for scenario 174, run 345.
# Power flow did not converge for scenario 174, run 351.
# Power flow did not converge for scenario 174, run 356.
# Power flow did not converge for scenario 174, run 359.
# Power flow did not converge for scenario 174, run 360.
# Power flow did not converge for scenario 174, run 362.
# Power flow did not converge for scenario 174, run 364.
# Power flow did not converge for scenario 174, run 366.
# Power flow did not converge for scenario 174, run 369.
# Power flow did not converge for scenario 174, run 372.
# Power flow did not converge for scenario 174, run 373.
# Power flow did not converge for scenario 174, run 375.
# Power flow did not converge for scenario 174, run 378.
# Power flow did not converge for scenario 174, run 381.
# Power flow did not converge for scenario 174, run 395.
# Power flow did not converge for scenario 174, run 397.
# Power flow did not converge for scenario 174, run 399.
# Power flow did not converge for scenario 174, run 407.
# Power flow did not converge for scenario 174, run 408.
# Power flow did not converge for scenario 174, run 411.
# Power flow did not converge for scenario 174, run 412.
# Power flow did not converge for scenario 174, run 424.
# Power flow did not converge for scenario 174, run 425.
# Power flow did not converge for scenario 174, run 429.
# Power flow did not converge for scenario 174, run 430.
# Power flow did not converge for scenario 174, run 434.
# Power flow did not converge for scenario 174, run 436.
# Power flow did not converge for scenario 174, run 437.
# Power flow did not converge for scenario 174, run 446.
# Power flow did not converge for scenario 174, run 447.
# Power flow did not converge for scenario 174, run 448.
# Power flow did not converge for scenario 174, run 449.
# Power flow did not converge for scenario 174, run 451.
# Power flow did not converge for scenario 174, run 453.
# Power flow did not converge for scenario 174, run 457.
# Power flow did not converge for scenario 174, run 462.
# Power flow did not converge for scenario 174, run 464.
# Power flow did not converge for scenario 174, run 475.
# Power flow did not converge for scenario 174, run 479.
# Power flow did not converge for scenario 174, run 480.
# Power flow did not converge for scenario 174, run 482.
# Power flow did not converge for scenario 174, run 483.
# Power flow did not converge for scenario 174, run 485.
# Power flow did not converge for scenario 174, run 488.
# Power flow did not converge for scenario 174, run 497.
# Scenario 175: Average LOLP = 0.18904109589041096
# Running Scenario 176/200
# ---------------------------------------------------------------------------
# LoadflowNotConverged                      Traceback (most recent call last)
# Cell In[70], line 33
#      30 net.line['length_km'] = net.line['length_km'] * (1 + np.random.uniform(-line_length_variation, line_length_variation, size=len(net.line)))
#      32 # Run power flow to update network parameters
# ---> 33 pp.runpp(net)
#      35 # Compute updated Z-matrix
#      36 Ybus, _, _ = makeYbus(net._ppc["baseMVA"], net._ppc["bus"], net._ppc["branch"])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandapower\run.py:250, in runpp(net, algorithm, calculate_voltage_angles, init, max_iteration, tolerance_mva, trafo_model, trafo_loading, enforce_q_lims, check_connectivity, voltage_depend_loads, consider_line_temperature, run_control, distributed_slack, tdpf, tdpf_delay_s, **kwargs)
#     248 _check_bus_index_and_print_warning_if_high(net)
#     249 _check_gen_index_and_print_warning_if_high(net)
# --> 250 _powerflow(net, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandapower\powerflow.py:86, in _powerflow(net, **kwargs)
#      84 result = _run_pf_algorithm(ppci, net["_options"], **kwargs)
#      85 # read the results (=ppci with results) to net
# ---> 86 _ppci_to_net(result, net)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandapower\powerflow.py:190, in _ppci_to_net(result, net)
#     188     algorithm = net["_options"]["algorithm"]
#     189     max_iteration = net["_options"]["max_iteration"]
# --> 190     raise LoadflowNotConverged("Power Flow {0} did not converge after "
#     191                                "{1} iterations!".format(algorithm, max_iteration))
#     192 else:
#     193     net["_ppc"] = result
#
# LoadflowNotConverged: Power Flow nr did not converge after 10 iterations!

# %% [markdown]
# ### Load the Collected Dataset for Causal Discovery and Inference

# %%
df = pd.read_excel('Causal_reliability_Results1.xlsx')
# View data structure
print(df.head())
# Out:
#    Scenario  Sgen1_ Mean_Solar Output  Sgen2_ Mean_Solar Output  \
# 0         1                  3.360836                  6.674337
# 1         2                 11.041304                  9.208804
# 2         3                  7.694836                  9.573787
# 3         4                  5.387546                  5.505342
# 4         5                 11.098567                  8.768585
#
#    Sgen3_ Mean_Solar Output  Sgen4_ Mean_Solar Output  \
# 0                  0.871857                  6.386660
# 1                  8.246664                  6.945839
# 2                  7.346230                 11.248355
# 3                  5.142512                 12.372902
# 4                  6.217769                  6.493718
#
#    Sgen5_ Mean_Solar Output  Sgen6_ Mean_Solar Output  \
# 0                  6.080782                  3.411541
# 1                  7.385348                 12.080513
# 2                  9.868687                  3.495921
# 3                  0.697367                 11.323325
# 4                  1.170674                  6.651645
#
#    Sgen7_ Mean_Solar Output  Sgen8_ Mean_Solar Output  \
# 0                  1.598468                  8.559769
# 1                 10.614391                 12.115445
# 2                 10.632534                  9.378344
# 3                 11.063353                  6.887160
# 4                  2.288372                  9.210124
#
#    Shortest Gen-to-Gen Impedance  Longest Gen-to-Gen Impedance  \
# 0                       8.656945                      8.657004
# 1                       9.560627                      9.560683
# 2                      10.311760                     10.311815
# 3                      10.335103                     10.335163
# 4                      10.561204                     10.561266
#
#    Shortest Load-to-Load Impedance  Longest Load-to-Load Impedance  \
# 0                         8.656476                        8.657026
# 1                         9.560094                        9.560715
# 2                        10.311243                       10.311847
# 3                        10.334605                       10.335191
# 4                        10.560687                       10.561292
#
#    Shortest Gen-to-Load Impedance  Longest Gen-to-Load Impedance  \
# 0                        8.656727                       8.657023
# 1                        9.560390                       9.560714
# 2                       10.311525                      10.311847
# 3                       10.334871                      10.335187
# 4                       10.560972                      10.561289
#
#    Total Solar Generation  Total Generation  Voltage Deviation   LOLP
# 0               36.944250        178.280362           0.000051  0.928
# 1               77.638308        227.635035           0.000039  0.000
# 2               69.238696        225.657046           0.000045  0.008
# 3               58.379507        201.715045           0.000041  0.074
# 4               51.899454        193.016189           0.000043  0.168

# %%
# Select variables for causal discovery 
#Assume the observational data without the latent confounders
selected_columns = [
    'Sgen1_ Mean_Solar Output', 
    'Sgen2_ Mean_Solar Output', 
    'Sgen3_ Mean_Solar Output', 
    'Sgen4_ Mean_Solar Output', 
    'Sgen5_ Mean_Solar Output', 
    'Sgen6_ Mean_Solar Output',
    'Sgen7_ Mean_Solar Output',
    'Sgen8_ Mean_Solar Output',
    'Shortest Gen-to-Gen Impedance', 'Longest Gen-to-Gen Impedance',
    'Shortest Load-to-Load Impedance', 'Longest Load-to-Load Impedance',
    'Shortest Gen-to-Load Impedance', 'Longest Gen-to-Load Impedance',
    'Total Solar Generation','Total Generation', 'Voltage Deviation',
    'LOLP'
]

df_selected = df[selected_columns]

# %%
# Standardize the data arrays and create the data object
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_selected), columns=df_selected.columns)
# Check for NaN values
print("Missing Values Check:")
print(df_scaled.isna().sum())

# Check for infinite values
if np.any(np.isinf(df_scaled.to_numpy())):
    print(" Warning: Infinite values detected in the dataset!")

# Drop NaN values
df_scaled = df_scaled.dropna()
# Out:
# Missing Values Check:
# Sgen1_ Mean_Solar Output           0
# Sgen2_ Mean_Solar Output           0
# Sgen3_ Mean_Solar Output           0
# Sgen4_ Mean_Solar Output           0
# Sgen5_ Mean_Solar Output           0
# Sgen6_ Mean_Solar Output           0
# Sgen7_ Mean_Solar Output           0
# Sgen8_ Mean_Solar Output           0
# Shortest Gen-to-Gen Impedance      0
# Longest Gen-to-Gen Impedance       0
# Shortest Load-to-Load Impedance    0
# Longest Load-to-Load Impedance     0
# Shortest Gen-to-Load Impedance     0
# Longest Gen-to-Load Impedance      0
# Total Solar Generation             0
# Total Generation                   0
# Voltage Deviation                  0
# LOLP                               0
# dtype: int64

# %% [markdown]
# ### Peter-Clark (PC) algorithm determines the causal skeleton (i.e., which variables are connected)

# %%
# Apply Peter-Clark Algorithm to Discover Causal Skeleton 
# Which calculates the Partial correlation between any two variables i and j, conditioned on a set of variables k.
print("Running PC Algorithm for Causal Graph Construction...")

pc_alg = pc(df_scaled.to_numpy(), alpha=0.05)  # Conditional Independence test
causal_graph = pc_alg.G

# Convert causal learn graph to NetworkX format
pc_nx_graph = nx.DiGraph() # Skeleton of the Causal graph

# Extract edges and add them to NetworkX graph
for i, j in zip(*np.where(causal_graph.graph != 0)):  
    pc_nx_graph.add_edge(df_selected.columns[i], df_selected.columns[j])  # Add edges using column names

# Draw the causal graph
plt.figure(figsize=(14, 13))
pos = nx.spring_layout(pc_nx_graph)  # Layout for better visualization
nx.draw(pc_nx_graph, pos, with_labels=True, node_color='lightblue', edge_color='black', node_size=3000, font_size=10)
plt.title("Estimated Causal Structure using PC Algorithm")
plt.show()
# Out:
# Running PC Algorithm for Causal Graph Construction...
#   0%|          | 0/18 [00:00<?, ?it/s]

# %% [markdown]
# ### Apply IGCI for Causal Drectionality

# %%
from __future__ import division
import numpy as np
from scipy.special import psi

def igci(x, y, refMeasure=1, estimator=2):
    """
    Information-Geometric Causal Inference (IGCI) method.

    Parameters:
        x (numpy.ndarray): 1D array representing variable X.
        y (numpy.ndarray): 1D array representing variable Y.
        refMeasure (int): Reference measure for scaling (1: min-max, 2: standardization).
        estimator (int): Estimation method (1: entropy-based, 2: slope-based).

    Returns:
        float: Causal asymmetry score f(x → y), higher values indicate stronger causal direction.
    """

    xi = np.real(x).reshape(-1, 1)
    yi = np.real(y).reshape(-1, 1)

    Lx, dimx = xi.shape
    Ly, dimy = yi.shape

    # ----- Input validation -----
    if dimx != 1 or dimy != 1:
        raise ValueError("Both x and y must be 1D arrays.")

    if Lx < 20 or Ly < 20:
        raise ValueError("Not enough observations in x or y (must be > 20).")

    if Lx != Ly:
        raise ValueError("Lengths of x and y must be equal.")
    # ----------------------------

    # Apply reference measure scaling
    if refMeasure == 1:  # Min-max normalization
        xi = (xi - np.min(xi)) / (np.max(xi) - np.min(xi))
        yi = (yi - np.min(yi)) / (np.max(yi) - np.min(yi))
    elif refMeasure == 2:  # Standardization
        xi = (xi - np.mean(xi)) / np.std(xi)
        yi = (yi - np.mean(yi)) / np.std(yi)
    else:
        print("Warning: Unknown reference measure - no scaling applied.")
        return None

    # ----- Estimation methods -----
    if estimator == 1:
        # Entropy-based estimator
        x1 = np.sort(xi, axis=0)
        y1 = np.sort(yi, axis=0)

        n1 = x1.shape[0]
        hx = np.sum(np.log(np.abs(np.diff(x1)))) / (n1 - 1) + psi(n1) - psi(1)

        n2 = y1.shape[0]
        hy = np.sum(np.log(np.abs(np.diff(y1)))) / (n2 - 1) + psi(n2) - psi(1)

        return hy - hx

    elif estimator == 2:
        # Slope-based estimator
        a, b = 0, 0

        ind1 = np.argsort(xi, axis=0)
        ind2 = np.argsort(yi, axis=0)

        for i in range(Lx - 1):
            # Compute slopes in x → y direction
            X1, X2 = xi[ind1[i, 0], 0], xi[ind1[i + 1, 0], 0]
            Y1, Y2 = yi[ind1[i, 0], 0], yi[ind1[i + 1, 0], 0]
            if (X1 != X2) and (Y1 != Y2):
                a += np.log(np.abs((Y2 - Y1) / (X2 - X1)))

            # Compute slopes in y → x direction
            X1, X2 = xi[ind2[i, 0], 0], xi[ind2[i + 1, 0], 0]
            Y1, Y2 = yi[ind2[i, 0], 0], yi[ind2[i + 1, 0], 0]
            if (X1 != X2) and (Y1 != Y2):
                b += np.log(np.abs((X2 - X1) / (Y2 - Y1)))

        return (a - b) / Lx

    else:
        raise ValueError("Unknown estimator. Use 1 (entropy-based) or 2 (slope-based).")

# %%
# Apply IGCI for Causal Drectionality
print("Applying IGCI Algorithm for Causal Direction...")
directed_graph = nx.DiGraph()  # Directed graph after IGCI
for edge in pc_nx_graph.edges():
    var_x, var_y = edge
    x_values = df_scaled[var_x].values
    y_values = df_scaled[var_y].values
    
    # Compute IGCI score
    igci_score = igci(x_values, y_values)  # Implement IGCI scoring method
    if igci_score > 0:  # X → Y
        directed_graph.add_edge(var_x, var_y)
    else:  # Y → X
        directed_graph.add_edge(var_y, var_x)

# Visualize the Final Causal Graph
plt.figure(figsize=(15, 10))
pos = nx.spring_layout(directed_graph)  # Layout for better visualization
nx.draw(directed_graph, pos, with_labels=True, node_color='lightblue', edge_color='black', node_size=3000, font_size=10, arrows=True)
plt.title("Final Causal Structure using PC + IGCI")
plt.show()
# Out:
# Applying IGCI Algorithm for Causal Direction...

# %% [markdown]
# ### Assign the scaled solar generation to the static generator

# %%
# # Assign the scaled generation to the static generator at 5 PV buses as injected photovoltaic output based on their capacities
# for i, bus in enumerate(pv_buses):
#     # Calculate the proportion of generation for each PV bus
#     bus_scaling_factor = installed_capacities[i] / total_installed_capacity
#     bus_generation_profile = scaled_pv_generation * bus_scaling_factor

#     # Add the generation profile to the DataFrame with a consistent column name
#     column_name = f'bus_{bus}_p_mw'
#     profiles_df[column_name] = bus_generation_profile.astype(float).values
#     # profiles_df[column_name] = bus_generation_profile.values

#     # Create a DFData object with the profiles DataFrame
#     data_source = DFData(profiles_df)

#     # Create ConstControl objects for each PV bus to update active power over time
#     for i, bus in enumerate(pv_buses):
#         element_index = net.sgen[net.sgen['bus'] == bus].index[0]
#         column_name = f'bus_{bus}_p_mw'
#         ConstControl(net, element='sgen', variable='p_mw', element_index=element_index, data_source=data_source,
#                      profile_name=column_name)

# %% [markdown]
# ## Time-Series Simulation
# Runs the power flow simulation iteratively for each time step. After each step, it computes the power flow and stores the results.

# %%
# Set up the output writer for results
# output_dir = "D:/My workspace/Results"#Home PC
output_dir = "C:/Apps-SU/My workspace/" #Lab PC
ow = OutputWriter(net, output_path=output_dir, output_file_type=".xlsx")
# Define record
ow.log_variable('res_sgen', 'p_mw')

# Define the number of time steps for the simulation
# time_steps = range(len(profiles_df))  # Define time steps as a range matching the data length
time_steps = list(range(0, 8760))
# Run the time-series simulation with the defined number of time steps
run_timeseries(net, time_steps=time_steps)
# Out:
# 100%|██████████| 8760/8760 [01:10<00:00, 124.01it/s]

# %% [markdown]
# ## Plot the PV Buses Power Function

# %%
# Assuming the Excel file has columns corresponding to the first 5 buses for PV generation profiles
# Define the output directory and updated file path for res_sgen
output_dir = "C:/Apps-SU/My workspace/res_sgen/"
result_file_path = os.path.join(output_dir, "p_mw.xlsx")
try:
    # Load the data from p_mw.xlsx for plotting
    pv_generation_data = pd.read_excel(result_file_path, usecols="B:F")  # Load columns B to F (2nd to 6th columns)
    plt.figure()
    plt.title('PV Generation Profile at Each PV Bus')

    # Plot each bus's generation profile from the loaded data
    for i, bus in enumerate(pv_buses):
        plt.plot(pv_generation_data.iloc[:, i], label=f'Bus {bus}')  # Use column for bus

    plt.xlabel('Time')
    plt.ylabel('PV Generation (MW)')
    plt.legend()
    plt.show()

except FileNotFoundError:
    print(f"File not found: {result_file_path}")

# %%
# Plotting the first 240 data points for each bus
plt.figure(figsize=(10, 6))
for i, bus in enumerate(pv_buses):
    plt.plot(pv_generation_data.index[:240], pv_generation_data.iloc[:240, i], label=f'Bus {bus}')

# Setting labels and title
plt.xlabel('Hours (2023)')
plt.ylabel('PV Generation (MW)')
plt.title('Hourly PV Generation (MW) for Selected Buses (240 Data Points:10days)')
plt.legend(title="PV Buses")
plt.grid(True)
plt.show()

# %%
# Plot histogram of the data to visually inspect distribution
plt.hist(pv_generation, bins=50, density=True, alpha=0.6, color='g')
plt.title("PV Generation Histogram")
plt.xlabel("MW")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Perform optimal power flow (OPF) analysis

# %%
pp.runopp(net)
print("OPF Results:")
print(net.res_bus)
print(net.res_line)
# Out:
# OPF Results:
#        vm_pu  va_degree       p_mw     q_mvar     lam_p         lam_q
# 0   1.000000   0.000000 -39.448392  19.949940  3.577936 -4.143238e-03
# 1   1.004029  -0.836057 -31.402858  -5.477128  3.608594 -2.971973e-08
# 2   0.999105  -2.239730   2.400000   1.200000  3.671995  4.266441e-03
# 3   0.999526  -2.655931   7.600000   1.600000  3.689274  5.221961e-03
# 4   0.995485  -2.371100   0.000000  -0.188288  3.660976  1.874167e-02
# 5   0.995131  -2.952487   0.000000   0.000000  3.694853  2.294117e-02
# 6   0.985949  -3.252072  22.800000  10.900000  3.715213  3.591101e-02
# 7   0.983916  -3.354916  30.000000  30.000000  6.855822  3.079593e+00
# 8   1.012731  -3.826598   0.000000   0.000000  3.760950  4.003894e-02
# 9   1.022042  -4.272397   5.800000   2.000000  3.794853  4.798086e-02
# 10  1.012731  -3.826598   0.000000   0.000000  3.760950  4.003829e-02
# 11  1.044342  -4.355654  11.200000   7.500000  3.756287  1.369208e-03
# 12  1.099003  -3.298512 -15.125197 -43.047720  3.756254  3.822850e-04
# 13  1.031991  -4.836009   6.200000   1.600000  3.814023  1.690134e-02
# 14  1.033005  -4.546523   8.200000   2.500000  3.804124  1.935835e-02
# 15  1.027927  -4.602030   3.500000   1.800000  3.794613  3.469313e-02
# 16  1.018665  -4.575412   9.000000   5.800000  3.809414  5.408544e-02
# 17  1.016799  -5.161179   3.200000   0.900000  3.856119  4.974204e-02
# 18  1.010651  -5.341509   9.500000   3.400000  3.870394  6.198030e-02
# 19  1.012613  -5.127674   2.200000   0.700000  3.855154  5.994678e-02
# 20  1.030638  -4.272894  17.500000  11.200000  3.807242  1.804240e-02
# 21  1.037032  -4.153641 -22.382124 -35.696559  3.797750  3.527752e-07
# 22  1.043101  -3.364309 -12.273321  -3.153330  3.773662 -1.308813e-06
# 23  1.033041  -3.312899   8.700000   6.657313  3.848663  2.906942e-03
# 24  1.050000  -0.913772   0.000000   0.000000  3.929113 -7.113254e-02
# 25  1.033044  -1.312582   3.500000   2.300000  3.992525 -2.882941e-02
# 26  1.068951   0.799067 -46.459450 -22.608502  4.024944  3.083031e-07
# 27  1.003024  -2.752165   0.000000   0.000000  4.347753  6.282913e-01
# 28  1.049999  -0.335621   2.400000   0.900000  3.993944 -2.132611e-01
# 29  1.039113  -1.129117  10.600000   1.900000  4.111724 -1.001637e-01
#     p_from_mw  q_from_mvar    p_to_mw  q_to_mvar         pl_mw   ql_mvar  \
# 0   20.014164   -14.708610 -19.899158  12.041519  1.150068e-01 -2.667092
# 1   19.434241    -5.241332 -19.236402   3.994911  1.978393e-01 -1.246421
# 2   17.598825    -4.261872 -17.408181   2.794904  1.906441e-01 -1.466968
# 3   16.836407    -5.194911 -16.805307   5.319314  3.110084e-02  0.124403
# 4   13.651359     0.047648 -13.558372  -1.674769  9.298624e-02 -1.627121
# 5   20.051839    -2.350149 -19.811453   1.072944  2.403854e-01 -1.277205
# 6   14.705057     7.337938 -14.678023  -7.229802  2.703404e-02  0.108136
# 7   13.558372     1.863057 -13.462815  -2.615263  9.555701e-02 -0.752206
# 8    9.382859     7.425347  -9.337183  -8.284737  4.567534e-02 -0.859390
# 9   22.760422    22.271407 -22.658022 -21.861808  1.023999e-01  0.409600
# 10   7.321197    -8.284212  -7.321197   8.543409  0.000000e+00  0.259197
# 11   4.183542    -4.733835  -4.183542   4.959530  8.881784e-16  0.225695
# 12   0.000000    -0.000000   0.000000  -0.000000  0.000000e+00 -0.000000
# 13   7.321199    -8.543408  -7.321199   8.679178  0.000000e+00  0.135770
# 14  11.908450   -17.052147 -11.908450  18.177941  0.000000e+00  1.125794
# 15 -15.125153   -40.635538  15.125153  43.048800  0.000000e+00  2.413262
# 16   4.757978     2.779346  -4.724570  -2.706964  3.340737e-02  0.072383
# 17   5.946826     5.910069  -5.901710  -5.826283  4.511581e-02  0.083787
# 18   5.128776     6.268228  -5.074647  -6.147942  5.412876e-02  0.120286
# 19  -1.475426     1.106971   1.482454  -1.100582  7.028117e-03  0.006389
# 20   1.574677     4.347933  -1.558487  -4.309481  1.619037e-02  0.038452
# 21   7.152041     4.060639  -7.082315  -3.921187  6.972601e-02  0.139452
# 22   3.882321     3.021185  -3.868277  -2.990756  1.404416e-02  0.030429
# 23  -5.631720    -0.409245   5.641084   0.431096  9.364582e-03  0.021851
# 24   7.896169     1.259634  -7.841082  -1.131096  5.508736e-02  0.128537
# 25   7.458147     1.534928  -7.441495  -1.490523  1.665183e-02  0.044405
# 26  -4.533554   -10.608728   4.571780  10.697921  3.822578e-02  0.089193
# 27  -5.116000    -7.824544   5.174567   7.950046  5.856756e-02  0.125502
# 28 -22.071769   -21.897924  22.162775  22.079936  9.100622e-02  0.182012
# 29 -10.932721     0.366197  11.044855  -0.141928  1.121344e-01  0.224269
# 30  -4.955220     5.666610   5.018448  -5.571768  6.322804e-02  0.094842
# 31   1.228495     3.295233  -1.213719  -3.264543  1.477684e-02  0.030690
# 32 -12.504727     2.178998  12.791579  -1.680781  2.868519e-01  0.498217
# 33   3.541090     2.362456  -3.500000  -2.300000  4.108963e-02  0.062456
# 34 -16.332668    -0.681674  16.599282   1.190666  2.666149e-01  0.508992
# 35 -16.603029   -16.017029  16.603029  18.133038  0.000000e+00  2.116008
# 36   6.156789     1.650882  -6.078560  -1.501535  7.822930e-02  0.149347
# 37   7.100348     1.633917  -6.951685  -1.355173  1.486631e-01  0.278743
# 38   3.678560     0.601535  -3.648315  -0.544827  3.024471e-02  0.056709
# 39  -7.341976    -8.138192   7.407248   6.381617  6.527172e-02 -1.756575
# 40  -9.158536   -10.521850   9.195781   9.635413  3.724451e-02 -0.886438
#
#     i_from_ka   i_to_ka      i_ka  vm_from_pu  va_from_degree  vm_to_pu  \
# 0    0.106222  0.099071  0.106222    1.000000        0.000000  1.004029
# 1    0.086083  0.084098  0.086083    1.000000        0.000000  0.999105
# 2    0.077129  0.075438  0.077129    1.004029       -0.836057  0.999526
# 3    0.075421  0.075421  0.075421    0.999105       -2.239730  0.999526
# 4    0.058148  0.058690  0.058690    1.004029       -0.836057  0.995485
# 5    0.085996  0.085266  0.085996    1.004029       -0.836057  0.995131
# 6    0.070317  0.070317  0.070317    0.999526       -2.655931  0.995131
# 7    0.058795  0.059488  0.059488    0.995485       -2.371100  0.985949
# 8    0.051423  0.054146  0.054146    0.995131       -2.952487  0.985949
# 9    0.136853  0.136853  0.136853    0.995131       -2.952487  0.983916
# 10   0.047513  0.047513  0.047513    0.995131       -2.952487  1.012731
# 11   0.027150  0.027150  0.027150    0.995131       -2.952487  1.022042
# 12   0.000000  0.000000  0.000000    1.012731       -3.826598  1.012731
# 13   0.047513  0.047513  0.047513    1.012731       -3.826598  1.022042
# 14   0.088991  0.088991  0.088991    0.999526       -2.655931  1.044342
# 15   0.177559  0.177559  0.177559    1.044342       -4.355654  1.099003
# 16   0.022565  0.022565  0.022565    1.044342       -4.355654  1.031991
# 17   0.034334  0.034334  0.034334    1.044342       -4.355654  1.033005
# 18   0.033166  0.033166  0.033166    1.044342       -4.355654  1.027927
# 19   0.007644  0.007644  0.007644    1.031991       -4.836009  1.033005
# 20   0.019239  0.019239  0.019239    1.027927       -4.602030  1.018665
# 21   0.034049  0.034049  0.034049    1.033005       -4.546523  1.016799
# 22   0.020691  0.020691  0.020691    1.016799       -5.161179  1.010651
# 23   0.023894  0.023894  0.023894    1.010651       -5.341509  1.012613
# 24   0.033459  0.033459  0.033459    1.022042       -4.272397  1.012613
# 25   0.031862  0.031862  0.031862    1.022042       -4.272397  1.018665
# 26   0.048275  0.048275  0.048275    1.022042       -4.272397  1.030638
# 27   0.039119  0.039119  0.039119    1.022042       -4.272397  1.037032
# 28   0.129015  0.129015  0.129015    1.030638       -4.272894  1.037032
# 29   0.045287  0.045287  0.045287    1.033005       -4.546523  1.043101
# 30   0.031043  0.031043  0.031043    1.037032       -4.153641  1.033041
# 31   0.014419  0.014419  0.014419    1.043101       -3.364309  1.033041
# 32   0.052548  0.052548  0.052548    1.033041       -3.312899  1.050000
# 33   0.017338  0.017338  0.017338    1.050000       -0.913772  1.033044
# 34   0.066581  0.066581  0.066581    1.050000       -0.913772  1.068951
# 35   0.098364  0.098364  0.098364    1.003024       -2.752165  1.068951
# 36   0.025502  0.025502  0.025502    1.068951        0.799067  1.049999
# 37   0.029150  0.029150  0.029150    1.068951        0.799067  1.039113
# 38   0.015182  0.015182  0.015182    1.049999       -0.335621  1.039113
# 39   0.047641  0.041688  0.047641    0.983916       -3.354916  1.003024
# 40   0.059949  0.056790  0.059949    0.995131       -2.952487  1.003024
#
#     va_to_degree  loading_percent
# 0      -0.836057        19.105902
# 1      -2.239730        15.483553
# 2      -2.655931        27.745925
# 3      -2.655931        13.565715
# 4      -2.371100        10.556442
# 5      -2.952487        30.935495
# 6      -2.952487        18.268924
# 7      -3.252072        19.871334
# 8      -3.252072         9.738985
# 9      -3.354916        99.999964
# 10     -3.826598        17.091957
# 11     -4.272397        19.838879
# 12     -3.826598         0.000000
# 13     -4.272397        17.091958
# 14     -4.355654        32.013219
# 15     -3.298512        63.874112
# 16     -4.836009        16.488476
# 17     -4.546523        25.087963
# 18     -4.602030        24.234987
# 19     -4.546523        11.170900
# 20     -4.575412        28.116642
# 21     -5.161179        49.760080
# 22     -5.341509        30.237941
# 23     -5.127674        17.459572
# 24     -5.127674        24.448642
# 25     -4.575412        23.282007
# 26     -4.272894        35.275044
# 27     -4.153641        28.584431
# 28     -4.153641        94.272618
# 29     -3.364309        66.183463
# 30     -3.312899        45.367438
# 31     -3.312899        21.071680
# 32     -0.913772        76.794853
# 33     -1.312582        25.338220
# 34      0.799067        97.302923
# 35      0.799067        35.384684
# 36     -0.335621        37.269486
# 37     -1.129117        42.599702
# 38     -1.129117        22.187027
# 39     -2.752165        34.811785
# 40     -2.752165        43.805416

# %% [markdown]
# ### The Mean and Standard Deviation values for each Static Generator(solar based energy) on the Pv bus

# %%
# Calculate mean and std for each PV bus from 2023 data
pv_bus_means =  pv_generation_data.mean()
pv_bus_stds =  pv_generation_data.std()

# Print the mean and standard deviation for each PV bus
print("Mean Generation for each PV bus:\n", pv_bus_means )
print("\nStandard Deviation for each PV bus:\n", pv_bus_stds)
# Out:
# Mean Generation for each PV bus:
#  0    20.42496
# 1    12.76560
# 2    14.04216
# 3     7.65936
# 4    10.21248
# dtype: float64
#
# Standard Deviation for each PV bus:
#  0    25.622111
# 1    16.013819
# 2    17.615201
# 3     9.608292
# 4    12.811055
# dtype: float64

# %% [markdown]
#  ## Monte Carlo Analysis for the System Reliability

# %%
# Set the number of Monte Carlo simulations
num_simulations = 8760

# %%
# ReLoad the 30-bus system model
net = pn.case30()
# Initialize arrays to store results
lolp_count = 0  # Count of loss of load events
unmet_demand_hours = 0  # Total hours of unmet demand

# Add static (PV) and traditional generators to each PV bus
for i, bus in enumerate(pv_buses):
    # Traditional generator (voltage-controlled generator)
    if f"Traditional_gen_{bus}" not in net.gen['name'].values:
        pp.create_gen(net, bus, p_mw=0, vm_pu=1.00, max_p_mw=50, name=f"Traditional_gen_{bus}")
    # Photovoltaic generator as a static generator (sgen)
    if f"PV_sgen_{bus}" not in net.sgen['name'].values:
        pp.create_sgen(net, bus, p_mw=pv_bus_means[i], max_p_mw=pv_bus_means[i] + pv_bus_stds[i], name=f"PV_sgen_{bus}")
        
# Run Monte Carlo simulations
for sim in range(num_simulations):
    # Sample PV generation for each bus
    pv_samples = [np.random.normal(pv_bus_means[i], pv_bus_stds[i]) for i in range(len(pv_buses))]
    
    # Assign PV generation to static generators
    for i, bus in enumerate(pv_buses):
        pv_sgen_index = net.sgen[net.sgen['bus'] == bus].index[0]
        net.sgen.at[pv_sgen_index, 'p_mw'] = pv_samples[i]
    
    # Run power flow
    pp.runpp(net)
    
    # Check for unmet demand
    total_generation = net.res_sgen['p_mw'].sum() + net.res_gen['p_mw'].sum()
    total_load = net.load['p_mw'].sum()
    
    if total_generation < total_load:
        lolp_count += 1
        unmet_demand_hours += 1

# Calculate reliability metrics
lolp = lolp_count / num_simulations
lole = lolp * num_simulations

print(f"Loss of Load Probability (LOLP): {lolp}")
print(f"Loss of Load Expectation (LOLE) over {num_simulations} hours: {lole}")
# Out:
# Loss of Load Probability (LOLP): 0.14143835616438355
# Loss of Load Expectation (LOLE) over 8760 hours: 1239.0

# %% [markdown]
# ## Generate structured datasets for Causal Inference Analysis
# Link the 5 PV bus outputs and other variables to the system reliability indicator's results.<br
#                                                                                                    >
# Build structured datasets, each scenario with varying PV generation profiles and system reliability outcomes.

# %%
# ReLoad the 30-Bus power system
net = pn.case30()

# Number of random scenarios
n_scenarios = 300

# Initialize a list to store structured datasets
structured_data = []

# Add static (PV) and traditional generators (Voltage control) to each PV bus 
for i, bus in enumerate(pv_buses):
    # Traditional generator (voltage-controlled generator)
    if f"Traditional_gen_{bus}" not in net.gen['name'].values:
       pp.create_gen(net, bus, p_mw=0, vm_pu=1.00, max_p_mw=50, name=f"Traditional_gen_{bus}")
    # Photovoltaic generator as a static generator (sgen)
    if f"PV_sgen_{bus}" not in net.sgen['name'].values:
       pp.create_sgen(net, bus, p_mw=0, max_p_mw=installed_capacity, name=f"PV_sgen_{bus}")

# Loop through scenarios to update sgen values
for scenario in range(n_scenarios):
    # Sample PV outputs from the normal distribution
    pv_outputs = [max(0, np.random.normal(mean, std)) for mean, std in zip(pv_bus_means, pv_bus_stds)]
    # Update the p_mw values for the PV static generators (sgen)
    for i, bus in enumerate(pv_buses):
        net.sgen.loc[net.sgen['name'] == f"PV_sgen_{bus}", 'p_mw'] = pv_outputs[i]

# Run power flow 
    try:
        pp.runpp(net)
        
        # Calculate reliability indicators (LOLP)
        total_generation = net.res_sgen['p_mw'].sum() + net.res_gen['p_mw'].sum()
        total_load = net.load['p_mw'].sum()
        lolp = 1 if total_generation < total_load else 0  # LOLP calculation

        total_reactive_power = net.res_gen['q_mvar'].sum() + net.res_sgen['q_mvar'].sum()  # Total reactive power
        voltage_deviation = net.res_bus['vm_pu'].std()  # Standard deviation of bus voltages
        
        # Collect scenario data
        scenario_data = {
            'Scenario': scenario + 1,
            'PV1 Output': pv_outputs[0],
            'PV2 Output': pv_outputs[1],
            'PV3 Output': pv_outputs[2],
            'PV4 Output': pv_outputs[3],
            'PV5 Output': pv_outputs[4],
            'Total Solar Generation': net.res_sgen['p_mw'].sum(),
            'Total Reactive Power': total_reactive_power,
             'Voltage Deviation': voltage_deviation,
            'Total Load': total_load,
            'LOLP': lolp
        }
        structured_data.append(scenario_data)
    except pp.LoadflowNotConverged:
        print(f"Scenario {scenario + 1}: Power flow did not converge.")
        continue
    
# Convert results to a DataFrame
df_results = pd.DataFrame(structured_data)

# Save results to an Excel file
df_results.to_excel("structured_data_30bus_cases.xlsx", index=False)
print("Structured data saved to 'structured_data_30bus_cases.xlsx'.")
# Out:
# Structured data saved to 'structured_data_30bus_cases.xlsx'.

# %% [markdown]
# ### Load the Experimental Results

# %%
import dowhy
from dowhy import CausalModel

# %%
data = pd.read_excel('structured_data_30bus_cases.xlsx')
# View data structure
print(data.head())
# Out:
#    Scenario  PV1 Output  PV2 Output  PV3 Output  PV4 Output  PV5 Output  \
# 0         1    0.000000    6.393316   27.201030    0.000000    0.000000
# 1         2    0.000000   19.166547   28.025689    2.440544    9.791505
# 2         3   34.797904   22.605885   15.125026    4.626306    0.000000
# 3         4    0.000000   22.407202    0.000000    2.403235    9.553918
# 4         5    7.935244   39.081118   13.709257    0.000000    0.058978
#
#    Total Solar Generation  Total Reactive Power  Voltage Deviation  \
# 0               33.594346             94.378938           0.011466
# 1               59.424284             90.136944           0.011570
# 2               77.155121             80.056367           0.011759
# 3               34.364355             92.618102           0.011687
# 4               60.784597             85.873080           0.011879
#
#    Total Load  LOLP
# 0       189.2     0
# 1       189.2     0
# 2       189.2     0
# 3       189.2     0
# 4       189.2     0

# %% [markdown]
# ### Define the Causal Model and  Estimate the Causal Effect

# %%
# Iterate over each PV bus output as the treatment variable
pv_buses = ['PV1 Output', 'PV2 Output', 'PV3 Output', 'PV4 Output', 'PV5 Output']

for pv_bus in pv_buses:
    print(f"Analyzing causal effect of {pv_bus} on LOLP:")
    # Define the causal model
    model = CausalModel(
    data=data,
    treatment=pv_bus,  # Treatments
    outcome='LOLP',  # Reliability indicator
    common_causes=['Total Load', 'Total Reactive Power']  # Confounders
)
    # Visualize the DAG
    model.view_model()

# Identify and estimate the causal effect
    identified_estimand = model.identify_effect()
    causal_estimate = model.estimate_effect(
        identified_estimand,
        method_name="backdoor.linear_regression"
    )
    
    print(f"Causal Effect of {pv_bus} on LOLP: {causal_estimate.value}")
    print("\n")
# Out:
# Analyzing causal effect of PV1 Output on LOLP:
# Causal Effect of PV1 Output on LOLP: 0.0037090191749719822
#
#
# Analyzing causal effect of PV2 Output on LOLP:
# Causal Effect of PV2 Output on LOLP: -0.00039432930504116476
#
#
# Analyzing causal effect of PV3 Output on LOLP:
# Causal Effect of PV3 Output on LOLP: -0.0018435076073529746
#
#
# Analyzing causal effect of PV4 Output on LOLP:
# Causal Effect of PV4 Output on LOLP: -0.0008868022422847954
#
#
# Analyzing causal effect of PV5 Output on LOLP:
# Causal Effect of PV5 Output on LOLP: -0.0021631845624823925

# %% [markdown]
# ### Improvement: Make Photovoltaic generators more significant in the system
# Make some improvements and refine the project, drop off some traditional generators(first check them and turn off some, to make sgen generator (pv generation) more significant, and then change the mean and std of the 5 PV buses（assume they all follow a normal distribution) to generate different scenarios.<br> Each scenario includes hundreds of run times(stochastic) and can consider the Monte Carlo method to get a corresponding lolp value(for example 0.734.)

# %%
# ReLoad the 30-Bus power system
net = pn.case30()     
# Inspect generators in the system
print(net.gen)
# Out:
#    name  bus   p_mw  vm_pu  sn_mva  min_q_mvar  max_q_mvar  scaling  slack  \
# 0  None    1  60.97    1.0     NaN       -20.0        60.0      1.0  False
# 1  None   21  21.59    1.0     NaN       -15.0        62.5      1.0  False
# 2  None   26  26.91    1.0     NaN       -15.0        48.7      1.0  False
# 3  None   22  19.20    1.0     NaN       -10.0        40.0      1.0  False
# 4  None   12  37.00    1.0     NaN       -15.0        44.7      1.0  False
#
#    in_service  slack_weight  type  controllable  max_p_mw  min_p_mw
# 0        True           0.0  None          True      80.0       0.0
# 1        True           0.0  None          True      50.0       0.0
# 2        True           0.0  None          True      55.0       0.0
# 3        True           0.0  None          True      30.0       0.0
# 4        True           0.0  None          True      40.0       0.0

# %%
# Drop specific generators

net.gen.drop(net.gen[net.gen['bus'].isin([22])].index, inplace=True)

# Verify the remaining generators
print(net.gen)
# Out:
#    name  bus   p_mw  vm_pu  sn_mva  min_q_mvar  max_q_mvar  scaling  slack  \
# 0  None    1  60.97    1.0     NaN       -20.0        60.0      1.0  False
# 1  None   21  21.59    1.0     NaN       -15.0        62.5      1.0  False
# 2  None   26  26.91    1.0     NaN       -15.0        48.7      1.0  False
# 4  None   12  37.00    1.0     NaN       -15.0        44.7      1.0  False
#
#    in_service  slack_weight  type  controllable  max_p_mw  min_p_mw
# 0        True           0.0  None          True      80.0       0.0
# 1        True           0.0  None          True      50.0       0.0
# 2        True           0.0  None          True      55.0       0.0
# 4        True           0.0  None          True      40.0       0.0

# %%
# Verify static generator table
print(net.sgen)
# Out:
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, scaling, in_service, type, current_source]
# Index: []

# %%
# Identify the 5 PV buses in the IEEE 30-bus system
pv_buses = [1, 21, 26, 22, 12]

# Create Static Generators (sgen) for the PV buses
for bus, installed_capacity in zip(pv_buses, installed_capacities):
    pp.create_sgen(net, bus, p_mw=0, max_p_mw=installed_capacity, name=f"PV_bus_{bus}")
    # Verify static generator table
print(net.sgen)
# Out:
#         name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0   PV_bus_1    1   0.0     0.0     NaN      1.0        True  wye
# 1  PV_bus_21   21   0.0     0.0     NaN      1.0        True  wye
# 2  PV_bus_26   26   0.0     0.0     NaN      1.0        True  wye
# 3  PV_bus_22   22   0.0     0.0     NaN      1.0        True  wye
# 4  PV_bus_12   12   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw
# 0            True      80.0
# 1            True      50.0
# 2            True      55.0
# 3            True      30.0
# 4            True      40.0

# %%
n_scenarios = 100  # Number of scenarios
n_runs_per_scenario = 500  # Monte Carlo runs per scenario
scenario_results = []
# Acceptable variation (Assume variation with the original mean and std)
mean_variation = 1
std_variation = 1

# %%
# Iterate over scenarios
for scenario in range(n_scenarios):
    scenario_lolps = []  # Store LOLP for each run in this scenario

# %% [markdown]
# ### Generate Scenarios for collect data

# %%
# Generate scenarios
for scenario in range(n_scenarios):
    # Adjust mean and std for this scenario
    print(f"Running Scenario {scenario + 1}/{n_scenarios}")
    lolp_count = 0  # To count the number of load losses
    scenario_means = [mean * (1 + np.random.uniform(-mean_variation, mean_variation)) for mean in pv_bus_means]
    scenario_stds = [std * (1 + np.random.uniform(-std_variation, std_variation)) for std in pv_bus_stds]
    
    scenario_lolps = []  # Store LOLP for each run in this scenario
    total_solar_generation = []
    total_reactive_power = []
    voltage_deviations = []
    for run in range(n_runs_per_scenario):
        # Sample PV outputs from normal distribution
        pv_outputs = [max(0, np.random.normal(mean, std)) for mean, std in zip(scenario_means, scenario_stds)]
        
        # Update PV generation in the network
        for i, bus in enumerate(pv_buses):
            net.sgen.loc[net.sgen['bus'] == bus, 'p_mw'] = pv_outputs[i]
        
        try:
            # Run power flow
            pp.runpp(net)
            
            # Calculate metrics
            total_generation = net.res_sgen['p_mw'].sum() + net.res_gen['p_mw'].sum()
            total_solar_generation.append(net.res_sgen['p_mw'].sum())
            total_reactive_power.append(net.res_bus['q_mvar'].sum())
            voltage_deviation = np.mean(abs(net.res_bus['vm_pu'] - 1.0))
            voltage_deviations.append(voltage_deviation)
            
            # Calculate voltage deviation from 1.0 p.u.
            voltage_dev = abs(net.res_bus['vm_pu'] - 1).mean()
            voltage_deviations.append(voltage_dev)
            
            # Calculate LOLP
            total_generation = net.res_sgen['p_mw'].sum() + net.res_gen['p_mw'].sum()
            total_load = net.load['p_mw'].sum()
            lolp = 1 if total_generation < total_load else 0  # Load loss if generation < load
            scenario_lolps.append(lolp)
        except pp.LoadflowNotConverged:
            print(f"Power flow did not converge for scenario {scenario}, run {run}.")
            continue
    
    # Calculate average LOLP for this scenario
    avg_lolp = np.mean(scenario_lolps) if scenario_lolps else None
    print(f"Scenario {scenario + 1}: Average LOLP = {avg_lolp}")
    avg_solar_generation = np.mean(total_solar_generation)
    avg_reactive_power = np.mean(total_reactive_power)
    avg_voltage_deviation = np.mean(voltage_deviations)
    
    # Calculate LOLP for this scenario
    lolp = lolp_count / n_runs_per_scenario
    scenario_results.append({
        'Scenario': scenario + 1,
        'PV1 Mean Output': scenario_means[0],
        'PV1 Std Output': scenario_stds[0],
        'PV2 Mean Output': scenario_means[1],
        'PV2 Std Output': scenario_stds[1],
        'PV3 Mean Output': scenario_means[2],
        'PV3 Std Output': scenario_stds[2],
        'PV4 Mean Output': scenario_means[3],
        'PV4 Std Output': scenario_stds[3],
        'PV5 Mean Output': scenario_means[4],
        'PV5 Std Output': scenario_stds[4],
        'Total Solar Generation': avg_solar_generation,
        'Total Reactive Power': avg_reactive_power,
        'Voltage Deviation': avg_voltage_deviation,
        'LOLP': avg_lolp
    })

# Save results to a DataFrame
df_scenario_results = pd.DataFrame(scenario_results)
df_scenario_results.to_excel("100_scenarios_drop1_results.xlsx", index=False)
print("Scenario results saved to '100_scenarios_drop1_results.xlsx'.")
# Out:
# Running Scenario 1/100
# Scenario 1: Average LOLP = 0.05
# Running Scenario 2/100
# Scenario 2: Average LOLP = 0.0
# Running Scenario 3/100
# Scenario 3: Average LOLP = 0.1
# Running Scenario 4/100
# Scenario 4: Average LOLP = 0.01
# Running Scenario 5/100
# Scenario 5: Average LOLP = 0.158
# Running Scenario 6/100
# Scenario 6: Average LOLP = 0.042
# Running Scenario 7/100
# Scenario 7: Average LOLP = 0.058
# Running Scenario 8/100
# Scenario 8: Average LOLP = 0.178
# Running Scenario 9/100
# Scenario 9: Average LOLP = 0.058
# Running Scenario 10/100
# Scenario 10: Average LOLP = 0.436
# Running Scenario 11/100
# Scenario 11: Average LOLP = 0.012
# Running Scenario 12/100
# Scenario 12: Average LOLP = 0.098
# Running Scenario 13/100
# Scenario 13: Average LOLP = 0.056
# Running Scenario 14/100
# Scenario 14: Average LOLP = 0.082
# Running Scenario 15/100
# Scenario 15: Average LOLP = 0.396
# Running Scenario 16/100
# Scenario 16: Average LOLP = 0.156
# Running Scenario 17/100
# Scenario 17: Average LOLP = 0.058
# Running Scenario 18/100
# Scenario 18: Average LOLP = 0.084
# Running Scenario 19/100
# Scenario 19: Average LOLP = 0.046
# Running Scenario 20/100
# Scenario 20: Average LOLP = 0.08
# Running Scenario 21/100
# Scenario 21: Average LOLP = 0.092
# Running Scenario 22/100
# Scenario 22: Average LOLP = 0.02
# Running Scenario 23/100
# Scenario 23: Average LOLP = 0.314
# Running Scenario 24/100
# Scenario 24: Average LOLP = 0.226
# Running Scenario 25/100
# Scenario 25: Average LOLP = 0.078
# Running Scenario 26/100
# Scenario 26: Average LOLP = 0.126
# Running Scenario 27/100
# Scenario 27: Average LOLP = 0.36
# Running Scenario 28/100
# Scenario 28: Average LOLP = 0.288
# Running Scenario 29/100
# Scenario 29: Average LOLP = 0.328
# Running Scenario 30/100
# Scenario 30: Average LOLP = 0.068
# Running Scenario 31/100
# Scenario 31: Average LOLP = 0.086
# Running Scenario 32/100
# Scenario 32: Average LOLP = 0.012
# Running Scenario 33/100
# Scenario 33: Average LOLP = 0.158
# Running Scenario 34/100
# Scenario 34: Average LOLP = 0.08
# Running Scenario 35/100
# Scenario 35: Average LOLP = 0.22
# Running Scenario 36/100
# Scenario 36: Average LOLP = 0.104
# Running Scenario 37/100
# Scenario 37: Average LOLP = 0.112
# Running Scenario 38/100
# Scenario 38: Average LOLP = 0.01
# Running Scenario 39/100
# Scenario 39: Average LOLP = 0.164
# Running Scenario 40/100
# Scenario 40: Average LOLP = 0.032
# Running Scenario 41/100
# Scenario 41: Average LOLP = 0.252
# Running Scenario 42/100
# Scenario 42: Average LOLP = 0.194
# Running Scenario 43/100
# Scenario 43: Average LOLP = 0.256
# Running Scenario 44/100
# Scenario 44: Average LOLP = 0.126
# Running Scenario 45/100
# Scenario 45: Average LOLP = 0.21
# Running Scenario 46/100
# Scenario 46: Average LOLP = 0.032
# Running Scenario 47/100
# Scenario 47: Average LOLP = 0.058
# Running Scenario 48/100
# Scenario 48: Average LOLP = 0.216
# Running Scenario 49/100
# Scenario 49: Average LOLP = 0.222
# Running Scenario 50/100
# Scenario 50: Average LOLP = 0.06
# Running Scenario 51/100
# Scenario 51: Average LOLP = 0.154
# Running Scenario 52/100
# Scenario 52: Average LOLP = 0.13
# Running Scenario 53/100
# Scenario 53: Average LOLP = 0.196
# Running Scenario 54/100
# Scenario 54: Average LOLP = 0.172
# Running Scenario 55/100
# Scenario 55: Average LOLP = 0.212
# Running Scenario 56/100
# Scenario 56: Average LOLP = 0.088
# Running Scenario 57/100
# Scenario 57: Average LOLP = 0.034
# Running Scenario 58/100
# Scenario 58: Average LOLP = 0.214
# Running Scenario 59/100
# Scenario 59: Average LOLP = 0.018
# Running Scenario 60/100
# Scenario 60: Average LOLP = 0.01
# Running Scenario 61/100
# Scenario 61: Average LOLP = 0.0
# Running Scenario 62/100
# Scenario 62: Average LOLP = 0.042
# Running Scenario 63/100
# Scenario 63: Average LOLP = 0.11
# Running Scenario 64/100
# Scenario 64: Average LOLP = 0.344
# Running Scenario 65/100
# Scenario 65: Average LOLP = 0.088
# Running Scenario 66/100
# Scenario 66: Average LOLP = 0.13
# Running Scenario 67/100
# Scenario 67: Average LOLP = 0.138
# Running Scenario 68/100
# Scenario 68: Average LOLP = 0.186
# Running Scenario 69/100
# Scenario 69: Average LOLP = 0.054
# Running Scenario 70/100
# Scenario 70: Average LOLP = 0.056
# Running Scenario 71/100
# Scenario 71: Average LOLP = 0.306
# Running Scenario 72/100
# Scenario 72: Average LOLP = 0.0
# Running Scenario 73/100
# Scenario 73: Average LOLP = 0.362
# Running Scenario 74/100
# Scenario 74: Average LOLP = 0.088
# Running Scenario 75/100
# Scenario 75: Average LOLP = 0.148
# Running Scenario 76/100
# Scenario 76: Average LOLP = 0.034
# Running Scenario 77/100
# Scenario 77: Average LOLP = 0.018
# Running Scenario 78/100
# Scenario 78: Average LOLP = 0.198
# Running Scenario 79/100
# Scenario 79: Average LOLP = 0.124
# Running Scenario 80/100
# Scenario 80: Average LOLP = 0.07
# Running Scenario 81/100
# Scenario 81: Average LOLP = 0.176
# Running Scenario 82/100
# Scenario 82: Average LOLP = 0.246
# Running Scenario 83/100
# Scenario 83: Average LOLP = 0.406
# Running Scenario 84/100
# Scenario 84: Average LOLP = 0.066
# Running Scenario 85/100
# Scenario 85: Average LOLP = 0.02
# Running Scenario 86/100
# Scenario 86: Average LOLP = 0.262
# Running Scenario 87/100
# Scenario 87: Average LOLP = 0.558
# Running Scenario 88/100
# Scenario 88: Average LOLP = 0.284
# Running Scenario 89/100
# Scenario 89: Average LOLP = 0.322
# Running Scenario 90/100
# Scenario 90: Average LOLP = 0.11
# Running Scenario 91/100
# Scenario 91: Average LOLP = 0.33
# Running Scenario 92/100
# Scenario 92: Average LOLP = 0.266
# Running Scenario 93/100
# Scenario 93: Average LOLP = 0.13
# Running Scenario 94/100
# Scenario 94: Average LOLP = 0.078
# Running Scenario 95/100
# Scenario 95: Average LOLP = 0.202
# Running Scenario 96/100
# Scenario 96: Average LOLP = 0.302
# Running Scenario 97/100
# Scenario 97: Average LOLP = 0.18
# Running Scenario 98/100
# Scenario 98: Average LOLP = 0.312
# Running Scenario 99/100
# Scenario 99: Average LOLP = 0.054
# Running Scenario 100/100
# Scenario 100: Average LOLP = 0.26
# Scenario results saved to '100_scenarios_drop1_results.xlsx'.

# %%
data = pd.read_excel('100_scenarios_drop1_results.xlsx')
# View data structure
print(data.head())
# Out:
#    Scenario  PV1 Mean Output  PV1 Std Output  PV2 Mean Output  PV2 Std Output  \
# 0         1        22.001459       32.655702        25.024449       30.656475
# 1         2        20.374236        4.573077         4.934383        8.254102
# 2         3        38.803690       16.423973         2.782887       30.873262
# 3         4        31.621034       10.705823        15.072737       10.991659
# 4         5         3.435557       23.048275        15.181540        8.275978
#
#    PV3 Mean Output  PV3 Std Output  PV4 Mean Output  PV4 Std Output  \
# 0        17.387559        2.258061         9.186479       11.584503
# 1        22.515850        4.844248        12.651198        9.748060
# 2         9.218810       15.303972         8.557404       13.845282
# 3        18.138888        0.301388         6.825625       15.915841
# 4         6.306105       12.880228        13.739654        5.455674
#
#    PV5 Mean Output  PV5 Std Output  Total Solar Generation  \
# 0        17.017713        9.408029               98.087642
# 1        19.981729        1.505005               82.518140
# 2         0.500316        0.143187               77.396223
# 3         3.454441       19.456361               86.255594
# 4        14.113254       11.404957               63.695811
#
#    Total Reactive Power  Voltage Deviation   LOLP
# 0             -1.713183           0.020811  0.050
# 1              0.673154           0.019832  0.000
# 2              3.733790           0.021082  0.100
# 3              2.342075           0.020673  0.010
# 4              3.560911           0.020197  0.158

# %%
# Iterate over each PV bus output as the treatment variable
pv_buses = ['PV1 Mean Output', 'PV2 Mean Output', 'PV3 Mean Output', 'PV4 Mean Output', 'PV5 Mean Output','Total Solar Generation']

for pv_bus in pv_buses:
    print(f"Analyzing causal effect of {pv_bus} on LOLP:")
    # Define the causal model
    model = CausalModel(
    data=data,
    treatment=pv_bus,  # Treatments
    outcome='LOLP',  # Reliability indicator
    common_causes=['Voltage Deviation', 'Total Reactive Power']  # Confounders
    )# Visualize the DAG
    model.view_model()

# Identify and estimate the causal effect
    identified_estimand = model.identify_effect()
    causal_estimate = model.estimate_effect(
        identified_estimand,
        method_name="backdoor.linear_regression"
    )
    
    print(f"Causal Effect of {pv_bus} on LOLP: {causal_estimate.value}")
    print("\n")
# Out:
# Analyzing causal effect of PV1 Mean Output on LOLP:
# Causal Effect of PV1 Mean Output on LOLP: -0.004355791576428292
#
#
# Analyzing causal effect of PV2 Mean Output on LOLP:
# Causal Effect of PV2 Mean Output on LOLP: -0.005948728250451979
#
#
# Analyzing causal effect of PV3 Mean Output on LOLP:
# Causal Effect of PV3 Mean Output on LOLP: -0.004124005821265014
#
#
# Analyzing causal effect of PV4 Mean Output on LOLP:
# Causal Effect of PV4 Mean Output on LOLP: -0.006589894702130145
#
#
# Analyzing causal effect of PV5 Mean Output on LOLP:
# Causal Effect of PV5 Mean Output on LOLP: -0.0024953879345202268
#
#
# Analyzing causal effect of Total Solar Generation on LOLP:
# Causal Effect of Total Solar Generation on LOLP: -0.007492839547257213

# %%
import pandapower.networks as pn

# Load the IEEE 30-bus system
net = pn.case30()

# Display parameters of the network
print("Buses:\n", net.bus)
print("Lines:\n", net.line)
print("Loads:\n", net.load)
print("Generators:\n", net.gen)
print("External Grid:\n", net.ext_grid)
print("Shunt Elements:\n", net.shunt)
print("Transformers:\n", net.trafo)
# Out:
# Buses:
#     name  vn_kv type zone  in_service  max_vm_pu  min_vm_pu
# 0     1  135.0    b  1.0        True       1.05       0.95
# 1     2  135.0    b  1.0        True       1.10       0.95
# 2     3  135.0    b  1.0        True       1.05       0.95
# 3     4  135.0    b  1.0        True       1.05       0.95
# 4     5  135.0    b  1.0        True       1.05       0.95
# 5     6  135.0    b  1.0        True       1.05       0.95
# 6     7  135.0    b  1.0        True       1.05       0.95
# 7     8  135.0    b  1.0        True       1.05       0.95
# 8     9  135.0    b  1.0        True       1.05       0.95
# 9    10  135.0    b  3.0        True       1.05       0.95
# 10   11  135.0    b  1.0        True       1.05       0.95
# 11   12  135.0    b  2.0        True       1.05       0.95
# 12   13  135.0    b  2.0        True       1.10       0.95
# 13   14  135.0    b  2.0        True       1.05       0.95
# 14   15  135.0    b  2.0        True       1.05       0.95
# 15   16  135.0    b  2.0        True       1.05       0.95
# 16   17  135.0    b  2.0        True       1.05       0.95
# 17   18  135.0    b  2.0        True       1.05       0.95
# 18   19  135.0    b  2.0        True       1.05       0.95
# 19   20  135.0    b  2.0        True       1.05       0.95
# 20   21  135.0    b  3.0        True       1.05       0.95
# 21   22  135.0    b  3.0        True       1.10       0.95
# 22   23  135.0    b  2.0        True       1.10       0.95
# 23   24  135.0    b  3.0        True       1.05       0.95
# 24   25  135.0    b  3.0        True       1.05       0.95
# 25   26  135.0    b  3.0        True       1.05       0.95
# 26   27  135.0    b  3.0        True       1.10       0.95
# 27   28  135.0    b  1.0        True       1.05       0.95
# 28   29  135.0    b  3.0        True       1.05       0.95
# 29   30  135.0    b  3.0        True       1.05       0.95
# Lines:
#      name std_type  from_bus  to_bus  length_km  r_ohm_per_km  x_ohm_per_km  \
# 0   None     None         0       1        1.0        3.6450       10.9350
# 1   None     None         0       2        1.0        9.1125       34.6275
# 2   None     None         1       3        1.0       10.9350       30.9825
# 3   None     None         2       3        1.0        1.8225        7.2900
# 4   None     None         1       4        1.0        9.1125       36.4500
# 5   None     None         1       5        1.0       10.9350       32.8050
# 6   None     None         3       5        1.0        1.8225        7.2900
# 7   None     None         4       6        1.0        9.1125       21.8700
# 8   None     None         5       6        1.0        5.4675       14.5800
# 9   None     None         5       7        1.0        1.8225        7.2900
# 10  None     None         5       8        1.0        0.0000       38.2725
# 11  None     None         5       9        1.0        0.0000      102.0600
# 12  None     None         8      10        1.0        0.0000       38.2725
# 13  None     None         8       9        1.0        0.0000       20.0475
# 14  None     None         3      11        1.0        0.0000       47.3850
# 15  None     None        11      12        1.0        0.0000       25.5150
# 16  None     None        11      13        1.0       21.8700       47.3850
# 17  None     None        11      14        1.0       12.7575       23.6925
# 18  None     None        11      15        1.0       16.4025       36.4500
# 19  None     None        13      14        1.0       40.0950       36.4500
# 20  None     None        15      16        1.0       14.5800       34.6275
# 21  None     None        14      17        1.0       20.0475       40.0950
# 22  None     None        17      18        1.0       10.9350       23.6925
# 23  None     None        18      19        1.0        5.4675       12.7575
# 24  None     None         9      19        1.0       16.4025       38.2725
# 25  None     None         9      16        1.0        5.4675       14.5800
# 26  None     None         9      20        1.0        5.4675       12.7575
# 27  None     None         9      21        1.0       12.7575       27.3375
# 28  None     None        20      21        1.0        1.8225        3.6450
# 29  None     None        14      22        1.0       18.2250       36.4500
# 30  None     None        21      23        1.0       21.8700       32.8050
# 31  None     None        22      23        1.0       23.6925       49.2075
# 32  None     None        23      24        1.0       34.6275       60.1425
# 33  None     None        24      25        1.0       45.5625       69.2550
# 34  None     None        24      26        1.0       20.0475       38.2725
# 35  None     None        27      26        1.0        0.0000       72.9000
# 36  None     None        26      28        1.0       40.0950       76.5450
# 37  None     None        26      29        1.0       58.3200      109.3500
# 38  None     None        28      29        1.0       43.7400       82.0125
# 39  None     None         7      27        1.0       10.9350       36.4500
# 40  None     None         5      27        1.0        3.6450       10.9350
#
#     c_nf_per_km  g_us_per_km  max_i_ka   df  parallel type  in_service  \
# 0    436.639076          0.0  0.555967  1.0         1   ol        True
# 1    291.092717          0.0  0.555967  1.0         1   ol        True
# 2    291.092717          0.0  0.277983  1.0         1   ol        True
# 3      0.000000          0.0  0.555967  1.0         1   ol        True
# 4    291.092717          0.0  0.555967  1.0         1   ol        True
# 5    291.092717          0.0  0.277983  1.0         1   ol        True
# 6      0.000000          0.0  0.384900  1.0         1   ol        True
# 7    145.546359          0.0  0.299367  1.0         1   ol        True
# 8    145.546359          0.0  0.555967  1.0         1   ol        True
# 9      0.000000          0.0  0.136853  1.0         1   ol        True
# 10     0.000000          0.0  0.277983  1.0         1   ol        True
# 11     0.000000          0.0  0.136853  1.0         1   ol        True
# 12     0.000000          0.0  0.277983  1.0         1   ol        True
# 13     0.000000          0.0  0.277983  1.0         1   ol        True
# 14     0.000000          0.0  0.277983  1.0         1   ol        True
# 15     0.000000          0.0  0.277983  1.0         1   ol        True
# 16     0.000000          0.0  0.136853  1.0         1   ol        True
# 17     0.000000          0.0  0.136853  1.0         1   ol        True
# 18     0.000000          0.0  0.136853  1.0         1   ol        True
# 19     0.000000          0.0  0.068427  1.0         1   ol        True
# 20     0.000000          0.0  0.068427  1.0         1   ol        True
# 21     0.000000          0.0  0.068427  1.0         1   ol        True
# 22     0.000000          0.0  0.068427  1.0         1   ol        True
# 23     0.000000          0.0  0.136853  1.0         1   ol        True
# 24     0.000000          0.0  0.136853  1.0         1   ol        True
# 25     0.000000          0.0  0.136853  1.0         1   ol        True
# 26     0.000000          0.0  0.136853  1.0         1   ol        True
# 27     0.000000          0.0  0.136853  1.0         1   ol        True
# 28     0.000000          0.0  0.136853  1.0         1   ol        True
# 29     0.000000          0.0  0.068427  1.0         1   ol        True
# 30     0.000000          0.0  0.068427  1.0         1   ol        True
# 31     0.000000          0.0  0.068427  1.0         1   ol        True
# 32     0.000000          0.0  0.068427  1.0         1   ol        True
# 33     0.000000          0.0  0.068427  1.0         1   ol        True
# 34     0.000000          0.0  0.068427  1.0         1   ol        True
# 35     0.000000          0.0  0.277983  1.0         1   ol        True
# 36     0.000000          0.0  0.068427  1.0         1   ol        True
# 37     0.000000          0.0  0.068427  1.0         1   ol        True
# 38     0.000000          0.0  0.068427  1.0         1   ol        True
# 39   291.092717          0.0  0.136853  1.0         1   ol        True
# 40   145.546359          0.0  0.136853  1.0         1   ol        True
#
#     max_loading_percent
# 0                 100.0
# 1                 100.0
# 2                 100.0
# 3                 100.0
# 4                 100.0
# 5                 100.0
# 6                 100.0
# 7                 100.0
# 8                 100.0
# 9                 100.0
# 10                100.0
# 11                100.0
# 12                100.0
# 13                100.0
# 14                100.0
# 15                100.0
# 16                100.0
# 17                100.0
# 18                100.0
# 19                100.0
# 20                100.0
# 21                100.0
# 22                100.0
# 23                100.0
# 24                100.0
# 25                100.0
# 26                100.0
# 27                100.0
# 28                100.0
# 29                100.0
# 30                100.0
# 31                100.0
# 32                100.0
# 33                100.0
# 34                100.0
# 35                100.0
# 36                100.0
# 37                100.0
# 38                100.0
# 39                100.0
# 40                100.0
# Loads:
#      name  bus  p_mw  q_mvar  const_z_percent  const_i_percent  sn_mva  \
# 0   None    1  21.7    12.7              0.0              0.0     NaN
# 1   None    2   2.4     1.2              0.0              0.0     NaN
# 2   None    3   7.6     1.6              0.0              0.0     NaN
# 3   None    6  22.8    10.9              0.0              0.0     NaN
# 4   None    7  30.0    30.0              0.0              0.0     NaN
# 5   None    9   5.8     2.0              0.0              0.0     NaN
# 6   None   11  11.2     7.5              0.0              0.0     NaN
# 7   None   13   6.2     1.6              0.0              0.0     NaN
# 8   None   14   8.2     2.5              0.0              0.0     NaN
# 9   None   15   3.5     1.8              0.0              0.0     NaN
# 10  None   16   9.0     5.8              0.0              0.0     NaN
# 11  None   17   3.2     0.9              0.0              0.0     NaN
# 12  None   18   9.5     3.4              0.0              0.0     NaN
# 13  None   19   2.2     0.7              0.0              0.0     NaN
# 14  None   20  17.5    11.2              0.0              0.0     NaN
# 15  None   22   3.2     1.6              0.0              0.0     NaN
# 16  None   23   8.7     6.7              0.0              0.0     NaN
# 17  None   25   3.5     2.3              0.0              0.0     NaN
# 18  None   28   2.4     0.9              0.0              0.0     NaN
# 19  None   29  10.6     1.9              0.0              0.0     NaN
#
#     scaling  in_service  type  controllable
# 0       1.0        True  None         False
# 1       1.0        True  None         False
# 2       1.0        True  None         False
# 3       1.0        True  None         False
# 4       1.0        True  None         False
# 5       1.0        True  None         False
# 6       1.0        True  None         False
# 7       1.0        True  None         False
# 8       1.0        True  None         False
# 9       1.0        True  None         False
# 10      1.0        True  None         False
# 11      1.0        True  None         False
# 12      1.0        True  None         False
# 13      1.0        True  None         False
# 14      1.0        True  None         False
# 15      1.0        True  None         False
# 16      1.0        True  None         False
# 17      1.0        True  None         False
# 18      1.0        True  None         False
# 19      1.0        True  None         False
# Generators:
#     name  bus   p_mw  vm_pu  sn_mva  min_q_mvar  max_q_mvar  scaling  slack  \
# 0  None    1  60.97    1.0     NaN       -20.0        60.0      1.0  False
# 1  None   21  21.59    1.0     NaN       -15.0        62.5      1.0  False
# 2  None   26  26.91    1.0     NaN       -15.0        48.7      1.0  False
# 3  None   22  19.20    1.0     NaN       -10.0        40.0      1.0  False
# 4  None   12  37.00    1.0     NaN       -15.0        44.7      1.0  False
#
#    in_service  slack_weight  type  controllable  max_p_mw  min_p_mw
# 0        True           0.0  None          True      80.0       0.0
# 1        True           0.0  None          True      50.0       0.0
# 2        True           0.0  None          True      55.0       0.0
# 3        True           0.0  None          True      30.0       0.0
# 4        True           0.0  None          True      40.0       0.0
# External Grid:
#     name  bus  vm_pu  va_degree  slack_weight  in_service  max_p_mw  min_p_mw  \
# 0  None    0    1.0        0.0           1.0        True      80.0       0.0
#
#    max_q_mvar  min_q_mvar
# 0       150.0       -20.0
# Shunt Elements:
#     bus  name  q_mvar  p_mw  vn_kv  step  max_step  in_service
# 0    4  None   -0.19   0.0  135.0     1         1        True
# 1   23  None   -0.04   0.0  135.0     1         1        True
# Transformers:
#  Empty DataFrame
# Columns: [name, std_type, hv_bus, lv_bus, sn_mva, vn_hv_kv, vn_lv_kv, vk_percent, vkr_percent, pfe_kw, i0_percent, shift_degree, tap_side, tap_neutral, tap_min, tap_max, tap_step_percent, tap_step_degree, tap_pos, tap_phase_shifter, parallel, df, in_service]
# Index: []
